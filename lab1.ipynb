# %% [markdown]
# # Лабораторная работа № 1 по прикладному программированию на python. Вариант № 2.

# %% [markdown]
# # Задание
#
# С использованием сервиса gismeteo получите данные о погоде в Самаре за максимально возможный период. Данные необходимо сохранить в выходном файле dataset.csv, где каждой строке будет соответсвовать отдельный день, а в строке через запятую будут указаны дата, температура, давление, данные о ветре.

# %%
from bs4 import BeautifulSoup
import csv
import os
import requests


def parser(year_from, year_to, step=1):
    parser_data = []
    for year in range(year_from, year_to + 1, step):
        for month in range(1, 13):
            URL = f"https://www.gismeteo.ru/diary/4618/{year}/{month}/"
            html_page = requests.get(
                URL, headers={"User-Agent": "Mozilla/5.0"})
            soup = BeautifulSoup(html_page.text, 'lxml')
            for day in soup.find_all('td', class_="first"):
                try:
                    temp = day.find_next()
                    press = temp.find_next()
                    wind = press.find_next_sibling().find_next_sibling().find_next_sibling()
                    parser_data.append([day.text + "." + str(month).zfill(2) + "." + str(year),
                                        temp.text + "°C", press.text + "мм.рт.ст.", wind.text])
                except:
                    print("Parsing error for " + day.text + "." + str(month).zfill(2) + "." + str(year))
    return parser_data


def upload_csv(parser_data):
    with open('dataset.csv', 'w', encoding="utf-8", newline="") as file:
        writer = csv.writer(file)
        writer.writerows(parser_data)


upload_csv(parser(2008, 2023))

print("Загрузка завершена")
# Out:
# Parsing error for 13.09.2015
# Parsing error for 5.01.2016
# Parsing error for 10.01.2016
# Parsing error for 24.04.2016
# Parsing error for 1.06.2016
# Parsing error for 13.12.2017
# Parsing error for 25.04.2018
# Parsing error for 29.07.2019
# Parsing error for 8.08.2021
# Загрузка завершена

# %% [markdown]
# # Получение нескольких выходных данных из файла dataset.csv

# %%
import csv
with open("dataset.csv", "r") as f:
    for line in csv.reader(f):
      print(line)
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# ['9.11.2009', '-1°C', '760мм.рт.ст.', 'ЮЗ 3м/с']
# ['10.11.2009', '+1°C', '759мм.рт.ст.', 'Ш']
# ['11.11.2009', '0°C', '759мм.рт.ст.', 'В 2м/с']
# ['12.11.2009', '+3°C', '758мм.рт.ст.', 'ЮВ 2м/с']
# ['13.11.2009', '+4°C', '761мм.рт.ст.', 'В 3м/с']
# ['14.11.2009', '+2°C', '764мм.рт.ст.', 'В 3м/с']
# ['15.11.2009', '+1°C', '762мм.рт.ст.', 'В 2м/с']
# ['16.11.2009', '+1°C', '759мм.рт.ст.', 'В 3м/с']
# ['17.11.2009', '0°C', '757мм.рт.ст.', 'В 4м/с']
# ['18.11.2009', '-1°C', '757мм.рт.ст.', 'Ш']
# ['19.11.2009', '0°C', '750мм.рт.ст.', 'ЮВ 2м/с']
# ['20.11.2009', '+1°C', '747мм.рт.ст.', 'В 1м/с']
# ['21.11.2009', '+1°C', '747мм.рт.ст.', 'СЗ 1м/с']
# ['22.11.2009', '0°C', '738мм.рт.ст.', 'ЮВ 2м/с']
# ['23.11.2009', '+1°C', '744мм.рт.ст.', 'Ш']
# ['24.11.2009', '+1°C', '750мм.рт.ст.', 'ЮЗ 2м/с']
# ['25.11.2009', '+3°C', '747мм.рт.ст.', 'Ю 2м/с']
# ['26.11.2009', '+3°C', '745мм.рт.ст.', 'Ю 1м/с']
# ['27.11.2009', '+4°C', '748мм.рт.ст.', 'ЮЗ 2м/с']
# ['28.11.2009', '+5°C', '751мм.рт.ст.', 'ЮЗ 1м/с']
# ['29.11.2009', '+7°C', '752мм.рт.ст.', 'ЮЗ 2м/с']
# ['30.11.2009', '+3°C', '753мм.рт.ст.', 'Ю 2м/с']
# ['1.12.2009', '+3°C', '758мм.рт.ст.', 'СЗ 1м/с']
# ['2.12.2009', '+1°C', '762мм.рт.ст.', 'Ю 2м/с']
# ['3.12.2009', '+1°C', '755мм.рт.ст.', 'З 4м/с']
# ['4.12.2009', '0°C', '752мм.рт.ст.', 'З 3м/с']
# ['5.12.2009', '-3°C', '759мм.рт.ст.', 'СВ 3м/с']
# ['6.12.2009', '-8°C', '763мм.рт.ст.', 'С 1м/с']
# ['7.12.2009', '-12°C', '766мм.рт.ст.', 'В 2м/с']
# ['8.12.2009', '-9°C', '765мм.рт.ст.', 'З 3м/с']
# ['9.12.2009', '-8°C', '760мм.рт.ст.', 'З 3м/с']
# ['10.12.2009', '-7°C', '761мм.рт.ст.', 'Ш']
# ['11.12.2009', '-10°C', '762мм.рт.ст.', 'В 1м/с']
# ['12.12.2009', '-10°C', '758мм.рт.ст.', 'В 2м/с']
# ['13.12.2009', '-9°C', '747мм.рт.ст.', 'В 1м/с']
# ['14.12.2009', '-11°C', '747мм.рт.ст.', 'С 1м/с']
# ['15.12.2009', '-23°C', '754мм.рт.ст.', 'С 2м/с']
# ['16.12.2009', '-24°C', '755мм.рт.ст.', 'СЗ 1м/с']
# ['17.12.2009', '-25°C', '761мм.рт.ст.', 'Ш']
# ['18.12.2009', '-22°C', '755мм.рт.ст.', 'Ш']
# ['19.12.2009', '-13°C', '751мм.рт.ст.', 'СВ 2м/с']
# ['20.12.2009', '-15°C', '755мм.рт.ст.', 'СВ 1м/с']
# ['21.12.2009', '-11°C', '755мм.рт.ст.', 'В 3м/с']
# ['22.12.2009', '-7°C', '753мм.рт.ст.', 'ЮВ 1м/с']
# ['23.12.2009', '-12°C', '764мм.рт.ст.', 'Ш']
# ['24.12.2009', '-9°C', '761мм.рт.ст.', 'Ю 3м/с']
# ['25.12.2009', '-4°C', '756мм.рт.ст.', 'Ю 3м/с']
# ['26.12.2009', '-3°C', '752мм.рт.ст.', 'Ш']
# ['27.12.2009', '-2°C', '740мм.рт.ст.', 'ЮВ 5м/с']
# ['28.12.2009', '+1°C', '744мм.рт.ст.', 'ЮЗ 4м/с']
# ['29.12.2009', '-2°C', '742мм.рт.ст.', 'В 2м/с']
# ['30.12.2009', '-2°C', '741мм.рт.ст.', 'ЮВ 2м/с']
# ['31.12.2009', '-2°C', '746мм.рт.ст.', 'ЮВ 2м/с']
# ['1.01.2010', '-4°C', '745мм.рт.ст.', 'В 3м/с']
# ['2.01.2010', '-5°C', '743мм.рт.ст.', 'В 2м/с']
# ['3.01.2010', '-3°C', '734мм.рт.ст.', 'В 1м/с']
# ['4.01.2010', '-17°C', '743мм.рт.ст.', 'СЗ 2м/с']
# ['5.01.2010', '-19°C', '757мм.рт.ст.', 'С 1м/с']
# ['6.01.2010', '-18°C', '763мм.рт.ст.', 'Ш']
# ['7.01.2010', '-17°C', '767мм.рт.ст.', 'СЗ 2м/с']
# ['8.01.2010', '-20°C', '766мм.рт.ст.', 'В 2м/с']
# ['9.01.2010', '-8°C', '761мм.рт.ст.', 'Ю 1м/с']
# ['10.01.2010', '-12°C', '760мм.рт.ст.', 'Ш']
# ['11.01.2010', '-14°C', '756мм.рт.ст.', 'ЮЗ 1м/с']
# ['12.01.2010', '-11°C', '752мм.рт.ст.', 'ЮЗ 2м/с']
# ['13.01.2010', '-7°C', '747мм.рт.ст.', 'З 3м/с']
# ['14.01.2010', '-8°C', '751мм.рт.ст.', 'СЗ 2м/с']
# ['15.01.2010', '-14°C', '761мм.рт.ст.', 'Ш']
# ['16.01.2010', '-17°C', '768мм.рт.ст.', 'Ш']
# ['17.01.2010', '-17°C', '774мм.рт.ст.', 'Ш']
# ['18.01.2010', '-18°C', '770мм.рт.ст.', 'З 2м/с']
# ['19.01.2010', '-17°C', '769мм.рт.ст.', 'В 1м/с']
# ['20.01.2010', '-17°C', '770мм.рт.ст.', 'В 1м/с']
# ['21.01.2010', '-15°C', '767мм.рт.ст.', 'Ш']
# ['22.01.2010', '-20°C', '763мм.рт.ст.', 'Ш']
# ['23.01.2010', '-22°C', '762мм.рт.ст.', 'Ш']
# ['24.01.2010', '-19°C', '761мм.рт.ст.', 'Ш']
# ['25.01.2010', '-14°C', '761мм.рт.ст.', 'В 2м/с']
# ['26.01.2010', '-7°C', '761мм.рт.ст.', 'В 4м/с']
# ['27.01.2010', '-12°C', '762мм.рт.ст.', 'В 3м/с']
# ['28.01.2010', '-14°C', '749мм.рт.ст.', 'В 2м/с']
# ['29.01.2010', '-15°C', '748мм.рт.ст.', 'В 1м/с']
# ['30.01.2010', '-16°C', '750мм.рт.ст.', 'В 4м/с']
# ['31.01.2010', '-7°C', '757мм.рт.ст.', 'В 1м/с']
# ['1.02.2010', '-5°C', '758мм.рт.ст.', 'ЮВ 3м/с']
# ['2.02.2010', '-7°C', '759мм.рт.ст.', 'В 3м/с']
# ['3.02.2010', '-11°C', '764мм.рт.ст.', 'В 3м/с']
# ['4.02.2010', '-9°C', '772мм.рт.ст.', 'В 2м/с']
# ['5.02.2010', '-9°C', '770мм.рт.ст.', 'Ш']
# ['6.02.2010', '-10°C', '767мм.рт.ст.', 'СЗ 1м/с']
# ['7.02.2010', '-11°C', '767мм.рт.ст.', 'З 1м/с']
# ['8.02.2010', '-13°C', '767мм.рт.ст.', 'В 2м/с']
# ['9.02.2010', '-14°C', '770мм.рт.ст.', 'В 4м/с']
# ['10.02.2010', '-15°C', '774мм.рт.ст.', 'ЮВ 2м/с']
# ['11.02.2010', '-16°C', '776мм.рт.ст.', 'ЮВ 2м/с']
# ['12.02.2010', '-12°C', '776мм.рт.ст.', 'В 1м/с']
# ['13.02.2010', '-10°C', '773мм.рт.ст.', 'З 1м/с']
# ['14.02.2010', '-10°C', '764мм.рт.ст.', 'В 3м/с']
# ['15.02.2010', '-10°C', '752мм.рт.ст.', 'ЮВ 3м/с']
# ['16.02.2010', '-7°C', '740мм.рт.ст.', 'В 2м/с']
# ['17.02.2010', '-6°C', '740мм.рт.ст.', 'СЗ 4м/с']
# ['18.02.2010', '-9°C', '751мм.рт.ст.', 'З 1м/с']
# ['19.02.2010', '-11°C', '746мм.рт.ст.', 'З 3м/с']
# ['20.02.2010', '-4°C', '745мм.рт.ст.', 'З 2м/с']
# ['21.02.2010', '-12°C', '743мм.рт.ст.', 'В 3м/с']
# ['22.02.2010', '-9°C', '743мм.рт.ст.', 'В 4м/с']
# ['23.02.2010', '-7°C', '743мм.рт.ст.', 'В 3м/с']
# ['24.02.2010', '-5°C', '746мм.рт.ст.', 'СВ 2м/с']
# ['25.02.2010', '-3°C', '749мм.рт.ст.', 'Ш']
# ['26.02.2010', '-3°C', '754мм.рт.ст.', 'Ш']
# ['27.02.2010', '-3°C', '755мм.рт.ст.', 'ЮЗ 2м/с']
# ['28.02.2010', '-6°C', '755мм.рт.ст.', 'СЗ 2м/с']
# ['1.03.2010', '-8°C', '758мм.рт.ст.', 'В 1м/с']
# ['2.03.2010', '-6°C', '755мм.рт.ст.', 'В 3м/с']
# ['3.03.2010', '-4°C', '752мм.рт.ст.', 'В 1м/с']
# ['4.03.2010', '-4°C', '750мм.рт.ст.', 'ЮВ 2м/с']
# ['5.03.2010', '0°C', '747мм.рт.ст.', 'ЮЗ 2м/с']
# ['6.03.2010', '-5°C', '753мм.рт.ст.', 'В 2м/с']
# ['7.03.2010', '-4°C', '749мм.рт.ст.', 'В 2м/с']
# ['8.03.2010', '-3°C', '740мм.рт.ст.', 'С 1м/с']
# ['9.03.2010', '-6°C', '749мм.рт.ст.', 'СЗ 2м/с']
# ['10.03.2010', '-4°C', '751мм.рт.ст.', 'ЮЗ 2м/с']
# ['11.03.2010', '-3°C', '746мм.рт.ст.', 'З 4м/с']
# ['12.03.2010', '-1°C', '751мм.рт.ст.', 'Ю 2м/с']
# ['13.03.2010', '0°C', '737мм.рт.ст.', 'ЮЗ 4м/с']
# ['14.03.2010', '0°C', '738мм.рт.ст.', 'З 2м/с']
# ['15.03.2010', '0°C', '742мм.рт.ст.', 'ЮЗ 4м/с']
# ['16.03.2010', '+1°C', '738мм.рт.ст.', 'ЮЗ 3м/с']
# ['17.03.2010', '-5°C', '746мм.рт.ст.', 'З 3м/с']
# ['18.03.2010', '-4°C', '754мм.рт.ст.', 'ЮЗ 2м/с']
# ['19.03.2010', '-7°C', '755мм.рт.ст.', 'З 4м/с']
# ['20.03.2010', '-2°C', '746мм.рт.ст.', 'ЮЗ 2м/с']
# ['21.03.2010', '+3°C', '746мм.рт.ст.', 'ЮЗ 1м/с']
# ['22.03.2010', '+3°C', '741мм.рт.ст.', 'З 3м/с']
# ['23.03.2010', '+2°C', '744мм.рт.ст.', 'СЗ 4м/с']
# ['24.03.2010', '+1°C', '749мм.рт.ст.', 'ЮЗ 4м/с']
# ['25.03.2010', '0°C', '749мм.рт.ст.', 'С 2м/с']
# ['26.03.2010', '0°C', '758мм.рт.ст.', 'СЗ 3м/с']
# ['27.03.2010', '+1°C', '758мм.рт.ст.', 'З 5м/с']
# ['28.03.2010', '+4°C', '758мм.рт.ст.', 'Ю 2м/с']
# ['29.03.2010', '+5°C', '758мм.рт.ст.', 'В 2м/с']
# ['30.03.2010', '+5°C', '757мм.рт.ст.', 'В 2м/с']
# ['31.03.2010', '+8°C', '757мм.рт.ст.', 'ЮВ 2м/с']
# ['1.04.2010', '+10°C', '757мм.рт.ст.', 'В 3м/с']
# ['2.04.2010', '+9°C', '759мм.рт.ст.', 'ЮВ 2м/с']
# ['3.04.2010', '+8°C', '758мм.рт.ст.', 'С 2м/с']
# ['4.04.2010', '+12°C', '757мм.рт.ст.', 'СВ 2м/с']
# ['5.04.2010', '+11°C', '756мм.рт.ст.', 'СВ 2м/с']
# ['6.04.2010', '+12°C', '755мм.рт.ст.', 'СВ 3м/с']
# ['7.04.2010', '+4°C', '759мм.рт.ст.', 'В 3м/с']
# ['8.04.2010', '+4°C', '761мм.рт.ст.', 'В 3м/с']
# ['9.04.2010', '+6°C', '758мм.рт.ст.', 'В 2м/с']
# ['10.04.2010', '+9°C', '755мм.рт.ст.', 'В 3м/с']
# ['11.04.2010', '+9°C', '754мм.рт.ст.', 'С 3м/с']
# ['12.04.2010', '+12°C', '753мм.рт.ст.', 'СВ 3м/с']
# ['13.04.2010', '+9°C', '752мм.рт.ст.', 'СЗ 2м/с']
# ['14.04.2010', '+8°C', '749мм.рт.ст.', 'СЗ 3м/с']
# ['15.04.2010', '+11°C', '752мм.рт.ст.', 'ЮЗ 2м/с']
# ['16.04.2010', '+13°C', '751мм.рт.ст.', 'З 2м/с']
# ['17.04.2010', '+17°C', '752мм.рт.ст.', 'Ю 3м/с']
# ['18.04.2010', '+13°C', '748мм.рт.ст.', 'ЮЗ 1м/с']
# ['19.04.2010', '+17°C', '749мм.рт.ст.', 'СЗ 3м/с']
# ['20.04.2010', '+20°C', '750мм.рт.ст.', 'ЮЗ 3м/с']
# ['21.04.2010', '+21°C', '751мм.рт.ст.', 'ЮВ 2м/с']
# ['22.04.2010', '+23°C', '747мм.рт.ст.', 'Ю 4м/с']
# ['23.04.2010', '+18°C', '748мм.рт.ст.', 'З 4м/с']
# ['24.04.2010', '+14°C', '758мм.рт.ст.', 'ЮЗ 3м/с']
# ['25.04.2010', '+17°C', '752мм.рт.ст.', 'ЮЗ 3м/с']
# ['26.04.2010', '+11°C', '749мм.рт.ст.', 'С 3м/с']
# ['27.04.2010', '+5°C', '750мм.рт.ст.', 'СВ 2м/с']
# ['28.04.2010', '+11°C', '749мм.рт.ст.', 'СЗ 5м/с']
# ['29.04.2010', '+15°C', '747мм.рт.ст.', 'З 4м/с']
# ['30.04.2010', '+17°C', '751мм.рт.ст.', 'ЮЗ 2м/с']
# ['1.05.2010', '+17°C', '752мм.рт.ст.', 'Ю 3м/с']
# ['2.05.2010', '+20°C', '753мм.рт.ст.', 'З 3м/с']
# ['3.05.2010', '+21°C', '754мм.рт.ст.', 'З 2м/с']
# ['4.05.2010', '+26°C', '755мм.рт.ст.', 'ЮЗ 3м/с']
# ['5.05.2010', '+28°C', '754мм.рт.ст.', 'З 1м/с']
# ['6.05.2010', '+29°C', '752мм.рт.ст.', 'СЗ 2м/с']
# ['7.05.2010', '+30°C', '751мм.рт.ст.', 'З 2м/с']
# ['8.05.2010', '+27°C', '753мм.рт.ст.', 'СВ 3м/с']
# ['9.05.2010', '+26°C', '751мм.рт.ст.', 'В 3м/с']
# ['10.05.2010', '+24°C', '752мм.рт.ст.', 'В 4м/с']
# ['11.05.2010', '+24°C', '755мм.рт.ст.', 'В 3м/с']
# ['12.05.2010', '+25°C', '755мм.рт.ст.', 'ЮВ 2м/с']
# ['13.05.2010', '+22°C', '754мм.рт.ст.', 'ЮВ 2м/с']
# ['14.05.2010', '+25°C', '751мм.рт.ст.', 'ЮВ 6м/с']
# ['15.05.2010', '+20°C', '752мм.рт.ст.', 'В 3м/с']
# ['16.05.2010', '+26°C', '750мм.рт.ст.', 'ЮВ 2м/с']
# ['17.05.2010', '+26°C', '747мм.рт.ст.', 'СЗ 1м/с']
# ['18.05.2010', '+21°C', '746мм.рт.ст.', 'СВ 2м/с']
# ['19.05.2010', '+22°C', '746мм.рт.ст.', 'С 2м/с']
# ['20.05.2010', '+20°C', '749мм.рт.ст.', 'СВ 4м/с']
# ['21.05.2010', '+18°C', '754мм.рт.ст.', 'ЮВ 2м/с']
# ['22.05.2010', '+21°C', '749мм.рт.ст.', 'ЮЗ 3м/с']
# ['23.05.2010', '+24°C', '746мм.рт.ст.', 'З 2м/с']
# ['24.05.2010', '+26°C', '743мм.рт.ст.', 'ЮВ 1м/с']
# ['25.05.2010', '+24°C', '741мм.рт.ст.', 'ЮВ 2м/с']
# ['26.05.2010', '+19°C', '737мм.рт.ст.', 'ЮВ 2м/с']
# ['27.05.2010', '+15°C', '738мм.рт.ст.', 'ЮЗ 4м/с']
# ['28.05.2010', '+13°C', '739мм.рт.ст.', 'ЮЗ 3м/с']
# ['29.05.2010', '+13°C', '747мм.рт.ст.', 'СЗ 2м/с']
# ['30.05.2010', '+20°C', '752мм.рт.ст.', 'В 2м/с']
# ['31.05.2010', '+23°C', '754мм.рт.ст.', 'З 2м/с']
# ['1.06.2010', '+26°C', '754мм.рт.ст.', 'ЮЗ 2м/с']
# ['2.06.2010', '+28°C', '754мм.рт.ст.', 'СЗ 1м/с']
# ['3.06.2010', '+31°C', '740мм.рт.ст.', 'З 2м/с']
# ['4.06.2010', '+33°C', '748мм.рт.ст.', 'ЮЗ 3м/с']
# ['5.06.2010', '+30°C', '743мм.рт.ст.', 'ЮЗ 2м/с']
# ['6.06.2010', '+20°C', '749мм.рт.ст.', 'С 2м/с']
# ['7.06.2010', '+22°C', '750мм.рт.ст.', 'СЗ 2м/с']
# ['8.06.2010', '+25°C', '748мм.рт.ст.', 'ЮЗ 2м/с']
# ['9.06.2010', '+29°C', '746мм.рт.ст.', 'ЮЗ 3м/с']
# ['10.06.2010', '+19°C', '748мм.рт.ст.', 'СВ 2м/с']
# ['11.06.2010', '+22°C', '749мм.рт.ст.', 'С 1м/с']
# ['12.06.2010', '+27°C', '749мм.рт.ст.', 'З 4м/с']
# ['13.06.2010', '+34°C', '745мм.рт.ст.', 'З 4м/с']
# ['14.06.2010', '+24°C', '744мм.рт.ст.', 'СЗ 1м/с']
# ['15.06.2010', '+27°C', '748мм.рт.ст.', 'С 3м/с']
# ['16.06.2010', '+29°C', '745мм.рт.ст.', 'С 1м/с']
# ['17.06.2010', '+27°C', '740мм.рт.ст.', 'СЗ 3м/с']
# ['18.06.2010', '+22°C', '743мм.рт.ст.', 'СЗ 2м/с']
# ['19.06.2010', '+20°C', '748мм.рт.ст.', 'С 3м/с']
# ['20.06.2010', '+25°C', '754мм.рт.ст.', 'С 2м/с']
# ['21.06.2010', '+26°C', '755мм.рт.ст.', 'С 2м/с']
# ['22.06.2010', '+28°C', '753мм.рт.ст.', 'С 2м/с']
# ['23.06.2010', '+32°C', '750мм.рт.ст.', 'В 2м/с']
# ['24.06.2010', '+33°C', '749мм.рт.ст.', 'З 2м/с']
# ['25.06.2010', '+35°C', '749мм.рт.ст.', 'СЗ 1м/с']
# ['26.06.2010', '+35°C', '749мм.рт.ст.', 'З 2м/с']
# ['27.06.2010', '+36°C', '750мм.рт.ст.', 'В 1м/с']
# ['28.06.2010', '+36°C', '747мм.рт.ст.', 'В 2м/с']
# ['29.06.2010', '+30°C', '747мм.рт.ст.', 'С 3м/с']
# ['30.06.2010', '+25°C', '748мм.рт.ст.', 'В 1м/с']
# ['1.07.2010', '+27°C', '749мм.рт.ст.', 'В 2м/с']
# ['2.07.2010', '+27°C', '750мм.рт.ст.', 'ЮВ 2м/с']
# ['3.07.2010', '+29°C', '749мм.рт.ст.', 'В 3м/с']
# ['4.07.2010', '+30°C', '746мм.рт.ст.', 'СЗ 2м/с']
# ['5.07.2010', '+31°C', '746мм.рт.ст.', 'СВ 3м/с']
# ['6.07.2010', '+30°C', '747мм.рт.ст.', 'СВ 2м/с']
# ['7.07.2010', '+31°C', '746мм.рт.ст.', 'В 2м/с']
# ['8.07.2010', '+32°C', '749мм.рт.ст.', 'В 2м/с']
# ['9.07.2010', '+34°C', '749мм.рт.ст.', 'З 2м/с']
# ['10.07.2010', '+35°C', '749мм.рт.ст.', 'З 3м/с']
# ['11.07.2010', '+36°C', '748мм.рт.ст.', 'З 2м/с']
# ['12.07.2010', '+33°C', '746мм.рт.ст.', 'СВ 3м/с']
# ['13.07.2010', '+27°C', '745мм.рт.ст.', 'С 3м/с']
# ['14.07.2010', '+26°C', '745мм.рт.ст.', 'СВ 4м/с']
# ['15.07.2010', '+26°C', '745мм.рт.ст.', 'С 3м/с']
# ['16.07.2010', '+31°C', '746мм.рт.ст.', 'СВ 5м/с']
# ['17.07.2010', '+35°C', '744мм.рт.ст.', 'С 3м/с']
# ['18.07.2010', '+35°C', '745мм.рт.ст.', 'З 2м/с']
# ['19.07.2010', '+28°C', '749мм.рт.ст.', 'В 2м/с']
# ['20.07.2010', '+29°C', '752мм.рт.ст.', 'ЮЗ 3м/с']
# ['21.07.2010', '+34°C', '750мм.рт.ст.', 'ЮЗ 3м/с']
# ['22.07.2010', '+35°C', '750мм.рт.ст.', 'СВ 1м/с']
# ['23.07.2010', '+35°C', '751мм.рт.ст.', 'З 2м/с']
# ['24.07.2010', '+37°C', '749мм.рт.ст.', 'СВ 1м/с']
# ['25.07.2010', '+36°C', '749мм.рт.ст.', 'ЮВ 2м/с']
# ['26.07.2010', '+38°C', '752мм.рт.ст.', 'С 2м/с']
# ['27.07.2010', '+35°C', '754мм.рт.ст.', 'В 1м/с']
# ['28.07.2010', '+36°C', '752мм.рт.ст.', 'СЗ 2м/с']
# ['29.07.2010', '+38°C', '752мм.рт.ст.', 'В 2м/с']
# ['30.07.2010', '+38°C', '751мм.рт.ст.', 'Ю 1м/с']
# ['31.07.2010', '+38°C', '752мм.рт.ст.', 'З 1м/с']
# ['1.08.2010', '+39°C', '752мм.рт.ст.', 'ЮЗ 2м/с']
# ['2.08.2010', '+40°C', '751мм.рт.ст.', 'СЗ 2м/с']
# ['3.08.2010', '+38°C', '749мм.рт.ст.', 'В 2м/с']
# ['4.08.2010', '+36°C', '749мм.рт.ст.', 'СВ 1м/с']
# ['5.08.2010', '+35°C', '752мм.рт.ст.', 'СВ 1м/с']
# ['6.08.2010', '+36°C', '753мм.рт.ст.', 'ЮВ 2м/с']
# ['7.08.2010', '+37°C', '752мм.рт.ст.', 'З 1м/с']
# ['8.08.2010', '+37°C', '751мм.рт.ст.', 'С 3м/с']
# ['9.08.2010', '+34°C', '752мм.рт.ст.', 'СВ 3м/с']
# ['10.08.2010', '+35°C', '752мм.рт.ст.', 'В 2м/с']
# ['11.08.2010', '+34°C', '752мм.рт.ст.', 'ЮЗ 1м/с']
# ['12.08.2010', '+36°C', '752мм.рт.ст.', 'ЮВ 2м/с']
# ['13.08.2010', '+36°C', '751мм.рт.ст.', 'ЮВ 2м/с']
# ['14.08.2010', '+32°C', '752мм.рт.ст.', 'СВ 3м/с']
# ['15.08.2010', '+27°C', '752мм.рт.ст.', 'С 3м/с']
# ['16.08.2010', '+29°C', '749мм.рт.ст.', 'З 2м/с']
# ['17.08.2010', '+29°C', '746мм.рт.ст.', 'СЗ 4м/с']
# ['18.08.2010', '+29°C', '746мм.рт.ст.', 'З 3м/с']
# ['19.08.2010', '+31°C', '739мм.рт.ст.', 'ЮЗ 4м/с']
# ['20.08.2010', '+27°C', '737мм.рт.ст.', 'ЮЗ 5м/с']
# ['21.08.2010', '+12°C', '742мм.рт.ст.', 'С 4м/с']
# ['22.08.2010', '+18°C', '748мм.рт.ст.', 'СЗ 3м/с']
# ['23.08.2010', '+25°C', '743мм.рт.ст.', 'З 3м/с']
# ['24.08.2010', '+23°C', '743мм.рт.ст.', 'З 2м/с']
# ['25.08.2010', '+27°C', '743мм.рт.ст.', 'З 3м/с']
# ['26.08.2010', '+31°C', '741мм.рт.ст.', 'ЮЗ 1м/с']
# ['27.08.2010', '+23°C', '743мм.рт.ст.', 'ЮЗ 2м/с']
# ['28.08.2010', '+24°C', '745мм.рт.ст.', 'З 2м/с']
# ['29.08.2010', '+32°C', '742мм.рт.ст.', 'ЮЗ 4м/с']
# ['30.08.2010', '+28°C', '741мм.рт.ст.', 'СЗ 3м/с']
# ['31.08.2010', '+20°C', '750мм.рт.ст.', 'СВ 1м/с']
# ['1.09.2010', '+19°C', '755мм.рт.ст.', 'В 2м/с']
# ['2.09.2010', '+29°C', '752мм.рт.ст.', 'В 6м/с']
# ['3.09.2010', '+29°C', '750мм.рт.ст.', 'СВ 2м/с']
# ['4.09.2010', '+23°C', '753мм.рт.ст.', 'З 2м/с']
# ['5.09.2010', '+19°C', '753мм.рт.ст.', 'С 1м/с']
# ['6.09.2010', '+19°C', '747мм.рт.ст.', 'С 3м/с']
# ['7.09.2010', '+13°C', '751мм.рт.ст.', 'СЗ 4м/с']
# ['8.09.2010', '+15°C', '755мм.рт.ст.', 'СЗ 1м/с']
# ['9.09.2010', '+17°C', '754мм.рт.ст.', 'СВ 3м/с']
# ['10.09.2010', '+18°C', '755мм.рт.ст.', 'З 3м/с']
# ['11.09.2010', '+17°C', '758мм.рт.ст.', 'СВ 2м/с']
# ['12.09.2010', '+20°C', '755мм.рт.ст.', 'З 2м/с']
# ['13.09.2010', '+15°C', '753мм.рт.ст.', 'В 2м/с']
# ['14.09.2010', '+17°C', '757мм.рт.ст.', 'В 2м/с']
# ['15.09.2010', '+19°C', '757мм.рт.ст.', 'З 2м/с']
# ['16.09.2010', '+23°C', '755мм.рт.ст.', 'З 3м/с']
# ['17.09.2010', '+25°C', '753мм.рт.ст.', 'ЮЗ 3м/с']
# ['18.09.2010', '+25°C', '753мм.рт.ст.', 'Ю 2м/с']
# ['19.09.2010', '+25°C', '752мм.рт.ст.', 'ЮЗ 3м/с']
# ['20.09.2010', '+26°C', '753мм.рт.ст.', 'ЮЗ 4м/с']
# ['21.09.2010', '+26°C', '752мм.рт.ст.', 'З 2м/с']
# ['22.09.2010', '+24°C', '752мм.рт.ст.', 'В 2м/с']
# ['23.09.2010', '+16°C', '747мм.рт.ст.', 'ЮВ 2м/с']
# ['24.09.2010', '+12°C', '746мм.рт.ст.', 'СЗ 2м/с']
# ['25.09.2010', '+13°C', '745мм.рт.ст.', 'С 3м/с']
# ['26.09.2010', '+19°C', '752мм.рт.ст.', 'З 2м/с']
# ['27.09.2010', '+20°C', '750мм.рт.ст.', 'З 3м/с']
# ['28.09.2010', '+20°C', '747мм.рт.ст.', 'ЮЗ 2м/с']
# ['29.09.2010', '+21°C', '740мм.рт.ст.', 'З 3м/с']
# ['30.09.2010', '+6°C', '746мм.рт.ст.', 'СЗ 2м/с']
# ['1.10.2010', '+7°C', '746мм.рт.ст.', 'СВ 3м/с']
# ['2.10.2010', '+9°C', '751мм.рт.ст.', 'СВ 3м/с']
# ['3.10.2010', '+6°C', '758мм.рт.ст.', 'З 2м/с']
# ['4.10.2010', '+5°C', '761мм.рт.ст.', 'СЗ 2м/с']
# ['5.10.2010', '+3°C', '761мм.рт.ст.', 'СВ 1м/с']
# ['6.10.2010', '+5°C', '761мм.рт.ст.', 'СВ 1м/с']
# ['7.10.2010', '+11°C', '760мм.рт.ст.', 'З 2м/с']
# ['8.10.2010', '+13°C', '761мм.рт.ст.', 'СЗ 1м/с']
# ['9.10.2010', '+14°C', '757мм.рт.ст.', 'В 1м/с']
# ['10.10.2010', '+14°C', '751мм.рт.ст.', 'З 1м/с']
# ['11.10.2010', '+14°C', '745мм.рт.ст.', 'Ю 3м/с']
# ['12.10.2010', '+14°C', '736мм.рт.ст.', 'ЮВ 2м/с']
# ['13.10.2010', '+4°C', '732мм.рт.ст.', 'ЮЗ 3м/с']
# ['14.10.2010', '+2°C', '738мм.рт.ст.', 'З 4м/с']
# ['15.10.2010', '+6°C', '745мм.рт.ст.', 'ЮЗ 3м/с']
# ['16.10.2010', '+10°C', '746мм.рт.ст.', 'З 3м/с']
# ['17.10.2010', '+5°C', '753мм.рт.ст.', 'СЗ 2м/с']
# ['18.10.2010', '+7°C', '758мм.рт.ст.', 'З 2м/с']
# ['19.10.2010', '+5°C', '761мм.рт.ст.', 'СВ 1м/с']
# ['20.10.2010', '+7°C', '764мм.рт.ст.', 'ЮВ 2м/с']
# ['21.10.2010', '+1°C', '754мм.рт.ст.', 'В 4м/с']
# ['22.10.2010', '+6°C', '749мм.рт.ст.', 'Ю 2м/с']
# ['23.10.2010', '+8°C', '756мм.рт.ст.', 'ЮЗ 4м/с']
# ['24.10.2010', '+8°C', '760мм.рт.ст.', 'Ю 1м/с']
# ['25.10.2010', '+8°C', '758мм.рт.ст.', 'В 1м/с']
# ['26.10.2010', '+8°C', '758мм.рт.ст.', 'ЮЗ 2м/с']
# ['27.10.2010', '+8°C', '752мм.рт.ст.', 'Ю 2м/с']
# ['28.10.2010', '+7°C', '744мм.рт.ст.', 'В 2м/с']
# ['29.10.2010', '+3°C', '744мм.рт.ст.', 'З 3м/с']
# ['30.10.2010', '+1°C', '749мм.рт.ст.', 'ЮЗ 2м/с']
# ['31.10.2010', '+1°C', '755мм.рт.ст.', 'СВ 2м/с']
# ['1.11.2010', '0°C', '755мм.рт.ст.', 'С 2м/с']
# ['2.11.2010', '+3°C', '750мм.рт.ст.', 'З 2м/с']
# ['3.11.2010', '+6°C', '752мм.рт.ст.', 'З 1м/с']
# ['4.11.2010', '+8°C', '750мм.рт.ст.', 'Ю 2м/с']
# ['5.11.2010', '+8°C', '739мм.рт.ст.', 'З 3м/с']
# ['6.11.2010', '+4°C', '735мм.рт.ст.', 'СЗ 2м/с']
# ['7.11.2010', '+2°C', '739мм.рт.ст.', 'СВ 1м/с']
# ['8.11.2010', '+5°C', '754мм.рт.ст.', 'Ю 1м/с']
# ['9.11.2010', '+3°C', '755мм.рт.ст.', 'ЮВ 2м/с']
# ['10.11.2010', '+7°C', '755мм.рт.ст.', 'ЮВ 1м/с']
# ['11.11.2010', '+8°C', '750мм.рт.ст.', 'Ю 2м/с']
# ['12.11.2010', '+6°C', '746мм.рт.ст.', 'Ю 1м/с']
# ['13.11.2010', '+8°C', '740мм.рт.ст.', 'ЮЗ 3м/с']
# ['14.11.2010', '+9°C', '741мм.рт.ст.', 'З 4м/с']
# ['15.11.2010', '+7°C', '754мм.рт.ст.', 'З 2м/с']
# ['16.11.2010', '+13°C', '752мм.рт.ст.', 'З 4м/с']
# ['17.11.2010', '+9°C', '754мм.рт.ст.', 'Ш']
# ['18.11.2010', '+1°C', '766мм.рт.ст.', 'В 2м/с']
# ['19.11.2010', '+1°C', '765мм.рт.ст.', 'В 2м/с']
# ['20.11.2010', '+1°C', '755мм.рт.ст.', 'ЮЗ 2м/с']
# ['21.11.2010', '-5°C', '758мм.рт.ст.', 'В 3м/с']
# ['22.11.2010', '-4°C', '752мм.рт.ст.', 'Ю 2м/с']
# ['23.11.2010', '0°C', '749мм.рт.ст.', 'Ш']
# ['24.11.2010', '+2°C', '749мм.рт.ст.', 'Ю 2м/с']
# ['25.11.2010', '+8°C', '743мм.рт.ст.', 'ЮЗ 3м/с']
# ['26.11.2010', '+3°C', '744мм.рт.ст.', 'З 3м/с']
# ['27.11.2010', '-1°C', '746мм.рт.ст.', 'В 3м/с']
# ['28.11.2010', '-1°C', '740мм.рт.ст.', 'СЗ 4м/с']
# ['29.11.2010', '-2°C', '752мм.рт.ст.', 'З 2м/с']
# ['30.11.2010', '+1°C', '728мм.рт.ст.', 'В 4м/с']
# ['1.12.2010', '-17°C', '741мм.рт.ст.', 'СЗ 4м/с']
# ['2.12.2010', '-19°C', '756мм.рт.ст.', 'СЗ 1м/с']
# ['3.12.2010', '-16°C', '767мм.рт.ст.', 'ЮВ 1м/с']
# ['4.12.2010', '-7°C', '761мм.рт.ст.', 'ЮВ 4м/с']
# ['5.12.2010', '-2°C', '752мм.рт.ст.', 'Ю 1м/с']
# ['6.12.2010', '0°C', '745мм.рт.ст.', 'ЮВ 2м/с']
# ['7.12.2010', '-6°C', '753мм.рт.ст.', 'Ш']
# ['8.12.2010', '-4°C', '753мм.рт.ст.', 'Ю 2м/с']
# ['9.12.2010', '-1°C', '750мм.рт.ст.', 'ЮВ 1м/с']
# ['10.12.2010', '0°C', '747мм.рт.ст.', 'В 3м/с']
# ['11.12.2010', '+2°C', '746мм.рт.ст.', 'В 4м/с']
# ['12.12.2010', '-3°C', '749мм.рт.ст.', 'В 3м/с']
# ['13.12.2010', '-3°C', '746мм.рт.ст.', 'В 4м/с']
# ['14.12.2010', '-2°C', '745мм.рт.ст.', 'ЮВ 2м/с']
# ['15.12.2010', '-3°C', '749мм.рт.ст.', 'ЮЗ 2м/с']
# ['16.12.2010', '-5°C', '751мм.рт.ст.', 'ЮЗ 5м/с']
# ['17.12.2010', '-4°C', '751мм.рт.ст.', 'Ш']
# ['18.12.2010', '-11°C', '752мм.рт.ст.', 'СВ 1м/с']
# ['19.12.2010', '-11°C', '755мм.рт.ст.', 'В 2м/с']
# ['20.12.2010', '-12°C', '754мм.рт.ст.', 'ЮВ 4м/с']
# ['21.12.2010', '-5°C', '756мм.рт.ст.', 'В 3м/с']
# ['22.12.2010', '-2°C', '753мм.рт.ст.', 'Ш']
# ['23.12.2010', '-5°C', '751мм.рт.ст.', 'Ш']
# ['24.12.2010', '-10°C', '757мм.рт.ст.', 'В 1м/с']
# ['25.12.2010', '-2°C', '750мм.рт.ст.', 'Ш']
# ['26.12.2010', '+2°C', '749мм.рт.ст.', 'ЮВ 1м/с']
# ['27.12.2010', '+3°C', '749мм.рт.ст.', 'Ю 1м/с']
# ['28.12.2010', '+1°C', '752мм.рт.ст.', 'Ш']
# ['29.12.2010', '-5°C', '760мм.рт.ст.', 'В 2м/с']
# ['30.12.2010', '+1°C', '761мм.рт.ст.', 'В 5м/с']
# ['31.12.2010', '-2°C', '756мм.рт.ст.', 'ЮВ 3м/с']
# ['1.01.2011', '-6°C', '753мм.рт.ст.', 'ЮВ 3м/с']
# ['2.01.2011', '-6°C', '751мм.рт.ст.', 'ЮВ 3м/с']
# ['3.01.2011', '-8°C', '755мм.рт.ст.', 'ЮВ 3м/с']
# ['4.01.2011', '-11°C', '760мм.рт.ст.', 'В 2м/с']
# ['5.01.2011', '-6°C', '756мм.рт.ст.', 'ЮВ 2м/с']
# ['6.01.2011', '-8°C', '764мм.рт.ст.', 'СВ 1м/с']
# ['7.01.2011', '-12°C', '769мм.рт.ст.', 'В 1м/с']
# ['8.01.2011', '-15°C', '767мм.рт.ст.', 'В 2м/с']
# ['9.01.2011', '-15°C', '767мм.рт.ст.', 'ЮВ 1м/с']
# ['10.01.2011', '-13°C', '765мм.рт.ст.', 'З 2м/с']
# ['11.01.2011', '-12°C', '761мм.рт.ст.', 'ЮЗ 2м/с']
# ['12.01.2011', '-8°C', '761мм.рт.ст.', 'З 1м/с']
# ['13.01.2011', '-11°C', '759мм.рт.ст.', 'ЮВ 1м/с']
# ['14.01.2011', '+10°C', '756мм.рт.ст.', 'В 3м/с']
# ['15.01.2011', '-5°C', '755мм.рт.ст.', 'В 3м/с']
# ['16.01.2011', '-9°C', '754мм.рт.ст.', 'В 4м/с']
# ['17.01.2011', '-9°C', '754мм.рт.ст.', 'В 5м/с']
# ['18.01.2011', '-14°C', '756мм.рт.ст.', 'СВ 3м/с']
# ['19.01.2011', '-13°C', '756мм.рт.ст.', 'В 2м/с']
# ['20.01.2011', '-14°C', '758мм.рт.ст.', 'З 1м/с']
# ['21.01.2011', '-17°C', '759мм.рт.ст.', 'С 1м/с']
# ['22.01.2011', '-16°C', '761мм.рт.ст.', 'В 2м/с']
# ['23.01.2011', '-14°C', '759мм.рт.ст.', 'ЮВ 3м/с']
# ['24.01.2011', '-10°C', '749мм.рт.ст.', 'ЮВ 4м/с']
# ['25.01.2011', '-5°C', '749мм.рт.ст.', 'Ш']
# ['26.01.2011', '-6°C', '749мм.рт.ст.', 'В 3м/с']
# ['27.01.2011', '-5°C', '749мм.рт.ст.', 'СЗ 1м/с']
# ['28.01.2011', '-11°C', '750мм.рт.ст.', 'З 2м/с']
# ['29.01.2011', '-10°C', '743мм.рт.ст.', 'З 3м/с']
# ['30.01.2011', '-7°C', '737мм.рт.ст.', 'ЮЗ 4м/с']
# ['31.01.2011', '-7°C', '745мм.рт.ст.', 'З 3м/с']
# ['1.02.2011', '-10°C', '749мм.рт.ст.', 'З 1м/с']
# ['2.02.2011', '-11°C', '747мм.рт.ст.', 'СЗ 1м/с']
# ['3.02.2011', '-14°C', '750мм.рт.ст.', 'ЮЗ 2м/с']
# ['4.02.2011', '-7°C', '748мм.рт.ст.', 'З 2м/с']
# ['5.02.2011', '-5°C', '740мм.рт.ст.', 'Ю 3м/с']
# ['6.02.2011', '-5°C', '728мм.рт.ст.', 'СВ 2м/с']
# ['7.02.2011', '-5°C', '733мм.рт.ст.', 'С 4м/с']
# ['8.02.2011', '-7°C', '741мм.рт.ст.', 'С 3м/с']
# ['9.02.2011', '-7°C', '730мм.рт.ст.', 'В 3м/с']
# ['10.02.2011', '-7°C', '731мм.рт.ст.', 'С 1м/с']
# ['11.02.2011', '-15°C', '740мм.рт.ст.', 'СЗ 2м/с']
# ['12.02.2011', '-15°C', '746мм.рт.ст.', 'В 1м/с']
# ['13.02.2011', '-11°C', '740мм.рт.ст.', 'В 5м/с']
# ['14.02.2011', '-12°C', '737мм.рт.ст.', 'ЮВ 2м/с']
# ['15.02.2011', '-15°C', '738мм.рт.ст.', 'В 1м/с']
# ['16.02.2011', '-17°C', '744мм.рт.ст.', 'СЗ 1м/с']
# ['17.02.2011', '-19°C', '746мм.рт.ст.', 'ЮЗ 1м/с']
# ['18.02.2011', '-18°C', '751мм.рт.ст.', 'СВ 2м/с']
# ['19.02.2011', '-18°C', '752мм.рт.ст.', 'З 2м/с']
# ['20.02.2011', '-17°C', '756мм.рт.ст.', 'ЮВ 1м/с']
# ['21.02.2011', '-19°C', '764мм.рт.ст.', 'СЗ 1м/с']
# ['22.02.2011', '-16°C', '768мм.рт.ст.', 'СЗ 3м/с']
# ['23.02.2011', '-14°C', '773мм.рт.ст.', 'С 2м/с']
# ['24.02.2011', '-13°C', '776мм.рт.ст.', 'ЮВ 1м/с']
# ['25.02.2011', '-14°C', '777мм.рт.ст.', 'ЮВ 1м/с']
# ['26.02.2011', '-13°C', '774мм.рт.ст.', 'В 1м/с']
# ['27.02.2011', '-13°C', '774мм.рт.ст.', 'В 1м/с']
# ['28.02.2011', '-10°C', '774мм.рт.ст.', 'ЮВ 1м/с']
# ['1.03.2011', '-8°C', '747мм.рт.ст.', 'Ш']
# ['2.03.2011', '-10°C', '761мм.рт.ст.', 'З 1м/с']
# ['3.03.2011', '-10°C', '758мм.рт.ст.', 'ЮВ 2м/с']
# ['4.03.2011', '-12°C', '749мм.рт.ст.', 'Ю 2м/с']
# ['5.03.2011', '-7°C', '737мм.рт.ст.', 'ЮЗ 3м/с']
# ['6.03.2011', '0°C', '732мм.рт.ст.', 'З 7м/с']
# ['7.03.2011', '-1°C', '749мм.рт.ст.', 'Ю 1м/с']
# ['8.03.2011', '-2°C', '756мм.рт.ст.', 'С 2м/с']
# ['9.03.2011', '-3°C', '761мм.рт.ст.', 'З 2м/с']
# ['10.03.2011', '-1°C', '763мм.рт.ст.', 'СЗ 2м/с']
# ['11.03.2011', '-3°C', '761мм.рт.ст.', 'В 2м/с']
# ['12.03.2011', '-3°C', '750мм.рт.ст.', 'ЮВ 1м/с']
# ['13.03.2011', '-5°C', '755мм.рт.ст.', 'Ю 1м/с']
# ['14.03.2011', '0°C', '759мм.рт.ст.', 'С 1м/с']
# ['15.03.2011', '+1°C', '751мм.рт.ст.', 'ЮЗ 4м/с']
# ['16.03.2011', '+1°C', '749мм.рт.ст.', 'С 1м/с']
# ['17.03.2011', '+1°C', '753мм.рт.ст.', 'СЗ 1м/с']
# ['18.03.2011', '-1°C', '756мм.рт.ст.', 'В 4м/с']
# ['19.03.2011', '-1°C', '758мм.рт.ст.', 'Ю 2м/с']
# ['20.03.2011', '-3°C', '760мм.рт.ст.', 'ЮВ 2м/с']
# ['21.03.2011', '-1°C', '759мм.рт.ст.', 'ЮВ 2м/с']
# ['22.03.2011', '-2°C', '754мм.рт.ст.', 'ЮВ 1м/с']
# ['23.03.2011', '+1°C', '743мм.рт.ст.', 'ЮЗ 3м/с']
# ['24.03.2011', '+1°C', '730мм.рт.ст.', 'ЮЗ 5м/с']
# ['25.03.2011', '-3°C', '727мм.рт.ст.', 'З 5м/с']
# ['26.03.2011', '-2°C', '741мм.рт.ст.', 'З 5м/с']
# ['27.03.2011', '-3°C', '748мм.рт.ст.', 'ЮЗ 5м/с']
# ['28.03.2011', '-2°C', '758мм.рт.ст.', 'З 2м/с']
# ['29.03.2011', '-3°C', '755мм.рт.ст.', 'Ю 3м/с']
# ['30.03.2011', '+2°C', '750мм.рт.ст.', 'ЮВ 1м/с']
# ['31.03.2011', '+5°C', '749мм.рт.ст.', 'З 4м/с']
# ['1.04.2011', '+1°C', '758мм.рт.ст.', 'СЗ 2м/с']
# ['2.04.2011', '+2°C', '764мм.рт.ст.', 'З 4м/с']
# ['3.04.2011', '+3°C', '763мм.рт.ст.', 'З 3м/с']
# ['4.04.2011', '+7°C', '764мм.рт.ст.', 'З 4м/с']
# ['5.04.2011', '+8°C', '761мм.рт.ст.', 'ЮВ 2м/с']
# ['6.04.2011', '+8°C', '752мм.рт.ст.', 'ЮВ 3м/с']
# ['7.04.2011', '+8°C', '741мм.рт.ст.', 'ЮВ 3м/с']
# ['8.04.2011', '+4°C', '735мм.рт.ст.', 'ЮВ 1м/с']
# ['9.04.2011', '+4°C', '734мм.рт.ст.', 'Ю 2м/с']
# ['10.04.2011', '+5°C', '731мм.рт.ст.', 'ЮЗ 4м/с']
# ['11.04.2011', '+7°C', '741мм.рт.ст.', 'ЮЗ 2м/с']
# ['12.04.2011', '+8°C', '746мм.рт.ст.', 'Ю 2м/с']
# ['13.04.2011', '+7°C', '746мм.рт.ст.', 'С 2м/с']
# ['14.04.2011', '+7°C', '738мм.рт.ст.', 'СЗ 3м/с']
# ['15.04.2011', '+5°C', '743мм.рт.ст.', 'З 2м/с']
# ['16.04.2011', '+7°C', '747мм.рт.ст.', 'В 4м/с']
# ['17.04.2011', '+8°C', '746мм.рт.ст.', 'З 3м/с']
# ['18.04.2011', '+11°C', '740мм.рт.ст.', 'ЮЗ 4м/с']
# ['19.04.2011', '+5°C', '737мм.рт.ст.', 'З 2м/с']
# ['20.04.2011', '+5°C', '744мм.рт.ст.', 'З 3м/с']
# ['21.04.2011', '+4°C', '749мм.рт.ст.', 'С 1м/с']
# ['22.04.2011', '+9°C', '752мм.рт.ст.', 'З 4м/с']
# ['23.04.2011', '+15°C', '753мм.рт.ст.', 'ЮЗ 3м/с']
# ['24.04.2011', '+13°C', '750мм.рт.ст.', 'СЗ 3м/с']
# ['25.04.2011', '+15°C', '748мм.рт.ст.', 'СЗ 3м/с']
# ['26.04.2011', '+11°C', '756мм.рт.ст.', 'З 2м/с']
# ['27.04.2011', '+15°C', '760мм.рт.ст.', 'ЮЗ 1м/с']
# ['28.04.2011', '+17°C', '752мм.рт.ст.', 'З 2м/с']
# ['29.04.2011', '+21°C', '748мм.рт.ст.', 'З 3м/с']
# ['30.04.2011', '+21°C', '749мм.рт.ст.', 'З 2м/с']
# ['1.05.2011', '+14°C', '748мм.рт.ст.', 'ЮВ 2м/с']
# ['2.05.2011', '+19°C', '744мм.рт.ст.', 'В 2м/с']
# ['3.05.2011', '+17°C', '739мм.рт.ст.', 'С 2м/с']
# ['4.05.2011', '+14°C', '742мм.рт.ст.', 'Ю 1м/с']
# ['5.05.2011', '+17°C', '746мм.рт.ст.', 'ЮВ 2м/с']
# ['6.05.2011', '+16°C', '753мм.рт.ст.', 'В 6м/с']
# ['7.05.2011', '+18°C', '760мм.рт.ст.', 'ЮВ 3м/с']
# ['8.05.2011', '+23°C', '758мм.рт.ст.', 'В 3м/с']
# ['9.05.2011', '+24°C', '755мм.рт.ст.', 'ЮВ 2м/с']
# ['10.05.2011', '+23°C', '751мм.рт.ст.', 'З 3м/с']
# ['11.05.2011', '+21°C', '746мм.рт.ст.', 'СВ 2м/с']
# ['12.05.2011', '+12°C', '749мм.рт.ст.', 'С 3м/с']
# ['13.05.2011', '+12°C', '748мм.рт.ст.', 'С 2м/с']
# ['14.05.2011', '+14°C', '748мм.рт.ст.', 'З 2м/с']
# ['15.05.2011', '+15°C', '752мм.рт.ст.', 'СВ 2м/с']
# ['16.05.2011', '+20°C', '753мм.рт.ст.', 'В 3м/с']
# ['17.05.2011', '+22°C', '753мм.рт.ст.', 'ЮЗ 1м/с']
# ['18.05.2011', '+21°C', '752мм.рт.ст.', 'З 2м/с']
# ['19.05.2011', '+21°C', '749мм.рт.ст.', 'З 3м/с']
# ['20.05.2011', '+21°C', '752мм.рт.ст.', 'З 2м/с']
# ['21.05.2011', '+26°C', '750мм.рт.ст.', 'З 3м/с']
# ['22.05.2011', '+26°C', '749мм.рт.ст.', 'С 2м/с']
# ['23.05.2011', '+25°C', '749мм.рт.ст.', 'С 2м/с']
# ['24.05.2011', '+22°C', '751мм.рт.ст.', 'С 3м/с']
# ['25.05.2011', '+21°C', '749мм.рт.ст.', 'Ю 2м/с']
# ['26.05.2011', '+22°C', '744мм.рт.ст.', 'ЮЗ 2м/с']
# ['27.05.2011', '+15°C', '744мм.рт.ст.', 'В 2м/с']
# ['28.05.2011', '+15°C', '744мм.рт.ст.', 'ЮВ 1м/с']
# ['29.05.2011', '+21°C', '750мм.рт.ст.', 'СЗ 3м/с']
# ['30.05.2011', '+26°C', '752мм.рт.ст.', 'ЮЗ 4м/с']
# ['31.05.2011', '+25°C', '751мм.рт.ст.', 'С 4м/с']
# ['1.06.2011', '+22°C', '750мм.рт.ст.', 'С 4м/с']
# ['2.06.2011', '+25°C', '747мм.рт.ст.', 'С 4м/с']
# ['3.06.2011', '+27°C', '743мм.рт.ст.', 'С 3м/с']
# ['4.06.2011', '+17°C', '737мм.рт.ст.', 'ЮЗ 2м/с']
# ['5.06.2011', '+15°C', '734мм.рт.ст.', 'З 4м/с']
# ['6.06.2011', '+18°C', '740мм.рт.ст.', 'СЗ 3м/с']
# ['7.06.2011', '+14°C', '746мм.рт.ст.', 'С 3м/с']
# ['8.06.2011', '+17°C', '743мм.рт.ст.', 'Ю 2м/с']
# ['9.06.2011', '+17°C', '741мм.рт.ст.', 'ЮВ 2м/с']
# ['10.06.2011', '+17°C', '738мм.рт.ст.', 'СЗ 2м/с']
# ['11.06.2011', '+17°C', '735мм.рт.ст.', 'СЗ 1м/с']
# ['12.06.2011', '+16°C', '740мм.рт.ст.', 'З 2м/с']
# ['13.06.2011', '+20°C', '744мм.рт.ст.', 'З 2м/с']
# ['14.06.2011', '+19°C', '747мм.рт.ст.', 'В 2м/с']
# ['15.06.2011', '+21°C', '745мм.рт.ст.', 'ЮВ 1м/с']
# ['16.06.2011', '+21°C', '746мм.рт.ст.', 'С 1м/с']
# ['17.06.2011', '+19°C', '745мм.рт.ст.', 'З 4м/с']
# ['18.06.2011', '+19°C', '745мм.рт.ст.', 'СЗ 4м/с']
# ['20.06.2011', '+25°C', '745мм.рт.ст.', 'Ш']
# ['21.06.2011', '+20°C', '743мм.рт.ст.', 'ЮВ 3м/с']
# ['22.06.2011', '+20°C', '738мм.рт.ст.', 'В 1м/с']
# ['23.06.2011', '+17°C', '738мм.рт.ст.', 'Ю 1м/с']
# ['24.06.2011', '+19°C', '740мм.рт.ст.', 'З 2м/с']
# ['25.06.2011', '+23°C', '742мм.рт.ст.', 'С 3м/с']
# ['26.06.2011', '+20°C', '741мм.рт.ст.', 'СВ 2м/с']
# ['27.06.2011', '+23°C', '744мм.рт.ст.', 'В 2м/с']
# ['28.06.2011', '+27°C', '749мм.рт.ст.', 'В 2м/с']
# ['29.06.2011', '+29°C', '750мм.рт.ст.', 'В 1м/с']
# ['30.06.2011', '+28°C', '749мм.рт.ст.', 'СВ 2м/с']
# ['1.07.2011', '+26°C', '750мм.рт.ст.', 'В 2м/с']
# ['2.07.2011', '+29°C', '749мм.рт.ст.', 'ЮВ 2м/с']
# ['3.07.2011', '+31°C', '747мм.рт.ст.', 'ЮВ 2м/с']
# ['4.07.2011', '+33°C', '746мм.рт.ст.', 'С 1м/с']
# ['5.07.2011', '+33°C', '746мм.рт.ст.', 'ЮВ 3м/с']
# ['6.07.2011', '+29°C', '748мм.рт.ст.', 'С 1м/с']
# ['7.07.2011', '+32°C', '749мм.рт.ст.', 'ЮВ 2м/с']
# ['8.07.2011', '+35°C', '745мм.рт.ст.', 'З 1м/с']
# ['9.07.2011', '+30°C', '743мм.рт.ст.', 'З 3м/с']
# ['10.07.2011', '+21°C', '740мм.рт.ст.', 'С 1м/с']
# ['11.07.2011', '+22°C', '746мм.рт.ст.', 'СВ 3м/с']
# ['12.07.2011', '+24°C', '749мм.рт.ст.', 'СЗ 3м/с']
# ['13.07.2011', '+27°C', '749мм.рт.ст.', 'СВ 2м/с']
# ['14.07.2011', '+26°C', '749мм.рт.ст.', 'З 3м/с']
# ['15.07.2011', '+27°C', '750мм.рт.ст.', 'СЗ 4м/с']
# ['16.07.2011', '+27°C', '751мм.рт.ст.', 'С 2м/с']
# ['17.07.2011', '+28°C', '749мм.рт.ст.', 'З 2м/с']
# ['18.07.2011', '+30°C', '746мм.рт.ст.', 'Ш']
# ['19.07.2011', '+32°C', '746мм.рт.ст.', 'З 2м/с']
# ['20.07.2011', '+31°C', '747мм.рт.ст.', 'З 2м/с']
# ['21.07.2011', '+30°C', '750мм.рт.ст.', 'ЮВ 2м/с']
# ['22.07.2011', '+27°C', '752мм.рт.ст.', 'В 2м/с']
# ['23.07.2011', '+29°C', '751мм.рт.ст.', 'В 2м/с']
# ['24.07.2011', '+31°C', '752мм.рт.ст.', 'СВ 2м/с']
# ['25.07.2011', '+32°C', '753мм.рт.ст.', 'СВ 2м/с']
# ['26.07.2011', '+36°C', '754мм.рт.ст.', 'Ю 2м/с']
# ['27.07.2011', '+27°C', '753мм.рт.ст.', 'СЗ 1м/с']
# ['28.07.2011', '+32°C', '747мм.рт.ст.', 'Ш']
# ['29.07.2011', '+34°C', '741мм.рт.ст.', 'С 3м/с']
# ['30.07.2011', '+31°C', '740мм.рт.ст.', 'З 3м/с']
# ['31.07.2011', '+29°C', '739мм.рт.ст.', 'С 2м/с']
# ['1.08.2011', '+21°C', '738мм.рт.ст.', 'С 1м/с']
# ['2.08.2011', '+18°C', '743мм.рт.ст.', 'Ю 2м/с']
# ['3.08.2011', '+21°C', '747мм.рт.ст.', 'С 3м/с']
# ['4.08.2011', '+22°C', '746мм.рт.ст.', 'В 3м/с']
# ['5.08.2011', '+19°C', '741мм.рт.ст.', 'В 2м/с']
# ['6.08.2011', '+22°C', '742мм.рт.ст.', 'СЗ 4м/с']
# ['7.08.2011', '+23°C', '749мм.рт.ст.', 'СЗ 3м/с']
# ['8.08.2011', '+27°C', '751мм.рт.ст.', 'ЮЗ 2м/с']
# ['9.08.2011', '+29°C', '752мм.рт.ст.', 'ЮЗ 3м/с']
# ['10.08.2011', '+32°C', '752мм.рт.ст.', 'СЗ 2м/с']
# ['11.08.2011', '+31°C', '751мм.рт.ст.', 'В 2м/с']
# ['12.08.2011', '+34°C', '748мм.рт.ст.', 'СВ 2м/с']
# ['13.08.2011', '+28°C', '748мм.рт.ст.', 'В 2м/с']
# ['14.08.2011', '+29°C', '747мм.рт.ст.', 'В 2м/с']
# ['15.08.2011', '+33°C', '746мм.рт.ст.', 'В 2м/с']
# ['16.08.2011', '+31°C', '746мм.рт.ст.', 'В 3м/с']
# ['17.08.2011', '+25°C', '746мм.рт.ст.', 'СВ 3м/с']
# ['18.08.2011', '+23°C', '746мм.рт.ст.', 'СВ 2м/с']
# ['19.08.2011', '+22°C', '746мм.рт.ст.', 'В 2м/с']
# ['20.08.2011', '+19°C', '747мм.рт.ст.', 'В 2м/с']
# ['21.08.2011', '+22°C', '746мм.рт.ст.', 'В 2м/с']
# ['22.08.2011', '+14°C', '742мм.рт.ст.', 'СВ 3м/с']
# ['23.08.2011', '+18°C', '744мм.рт.ст.', 'С 3м/с']
# ['24.08.2011', '+13°C', '749мм.рт.ст.', 'ЮВ 1м/с']
# ['25.08.2011', '+18°C', '751мм.рт.ст.', 'С 3м/с']
# ['26.08.2011', '+22°C', '754мм.рт.ст.', 'З 2м/с']
# ['27.08.2011', '+22°C', '752мм.рт.ст.', 'СЗ 3м/с']
# ['28.08.2011', '+20°C', '746мм.рт.ст.', 'З 2м/с']
# ['29.08.2011', '+21°C', '750мм.рт.ст.', 'Ш']
# ['30.08.2011', '+27°C', '750мм.рт.ст.', 'З 2м/с']
# ['31.08.2011', '+30°C', '750мм.рт.ст.', 'ЮЗ 1м/с']
# ['1.09.2011', '+29°C', '749мм.рт.ст.', 'З 3м/с']
# ['2.09.2011', '+28°C', '746мм.рт.ст.', 'Ю 3м/с']
# ['3.09.2011', '+22°C', '743мм.рт.ст.', 'Ш']
# ['4.09.2011', '+21°C', '749мм.рт.ст.', 'СВ 1м/с']
# ['5.09.2011', '+19°C', '748мм.рт.ст.', 'СВ 2м/с']
# ['6.09.2011', '+18°C', '737мм.рт.ст.', 'В 1м/с']
# ['7.09.2011', '+13°C', '736мм.рт.ст.', 'Ю 2м/с']
# ['8.09.2011', '+14°C', '738мм.рт.ст.', 'З 2м/с']
# ['9.09.2011', '+20°C', '739мм.рт.ст.', 'ЮВ 2м/с']
# ['10.09.2011', '+16°C', '737мм.рт.ст.', 'ЮЗ 4м/с']
# ['11.09.2011', '+16°C', '740мм.рт.ст.', 'ЮЗ 3м/с']
# ['12.09.2011', '+14°C', '740мм.рт.ст.', 'Ю 1м/с']
# ['13.09.2011', '+15°C', '740мм.рт.ст.', 'Ш']
# ['14.09.2011', '+17°C', '746мм.рт.ст.', 'З 3м/с']
# ['15.09.2011', '+22°C', '745мм.рт.ст.', 'СЗ 3м/с']
# ['16.09.2011', '+15°C', '746мм.рт.ст.', 'ЮВ 1м/с']
# ['17.09.2011', '+17°C', '746мм.рт.ст.', 'С 1м/с']
# ['18.09.2011', '+15°C', '747мм.рт.ст.', 'З 2м/с']
# ['19.09.2011', '+15°C', '752мм.рт.ст.', 'СЗ 2м/с']
# ['20.09.2011', '+14°C', '752мм.рт.ст.', 'СЗ 3м/с']
# ['21.09.2011', '+10°C', '745мм.рт.ст.', 'З 2м/с']
# ['22.09.2011', '+10°C', '749мм.рт.ст.', 'СЗ 2м/с']
# ['23.09.2011', '+13°C', '748мм.рт.ст.', 'З 2м/с']
# ['24.09.2011', '+20°C', '747мм.рт.ст.', 'ЮЗ 3м/с']
# ['25.09.2011', '+10°C', '743мм.рт.ст.', 'В 1м/с']
# ['26.09.2011', '+11°C', '744мм.рт.ст.', 'З 6м/с']
# ['27.09.2011', '+9°C', '749мм.рт.ст.', 'СЗ 2м/с']
# ['28.09.2011', '+9°C', '749мм.рт.ст.', 'ЮЗ 2м/с']
# ['29.09.2011', '+10°C', '743мм.рт.ст.', 'З 4м/с']
# ['30.09.2011', '+13°C', '749мм.рт.ст.', 'Ю 1м/с']
# ['1.10.2011', '+12°C', '737мм.рт.ст.', 'ЮЗ 2м/с']
# ['2.10.2011', '+7°C', '731мм.рт.ст.', 'СВ 3м/с']
# ['3.10.2011', '+10°C', '737мм.рт.ст.', 'ЮЗ 1м/с']
# ['4.10.2011', '+9°C', '741мм.рт.ст.', 'СЗ 2м/с']
# ['5.10.2011', '+9°C', '744мм.рт.ст.', 'ЮЗ 2м/с']
# ['6.10.2011', '+12°C', '742мм.рт.ст.', 'СЗ 2м/с']
# ['7.10.2011', '+14°C', '749мм.рт.ст.', 'З 2м/с']
# ['8.10.2011', '+16°C', '751мм.рт.ст.', 'ЮЗ 3м/с']
# ['9.10.2011', '+17°C', '756мм.рт.ст.', 'Ю 3м/с']
# ['10.10.2011', '+17°C', '755мм.рт.ст.', 'ЮВ 2м/с']
# ['11.10.2011', '+15°C', '749мм.рт.ст.', 'Ю 3м/с']
# ['12.10.2011', '+17°C', '746мм.рт.ст.', 'ЮЗ 3м/с']
# ['13.10.2011', '+19°C', '739мм.рт.ст.', 'ЮЗ 3м/с']
# ['14.10.2011', '+11°C', '749мм.рт.ст.', 'З 2м/с']
# ['15.10.2011', '+10°C', '754мм.рт.ст.', 'СЗ 1м/с']
# ['16.10.2011', '+6°C', '756мм.рт.ст.', 'СЗ 2м/с']
# ['17.10.2011', '+6°C', '759мм.рт.ст.', 'З 2м/с']
# ['18.10.2011', '+7°C', '759мм.рт.ст.', 'ЮВ 1м/с']
# ['19.10.2011', '+9°C', '755мм.рт.ст.', 'В 2м/с']
# ['20.10.2011', '+12°C', '756мм.рт.ст.', 'ЮВ 1м/с']
# ['21.10.2011', '+15°C', '757мм.рт.ст.', 'Ю 1м/с']
# ['22.10.2011', '+8°C', '755мм.рт.ст.', 'СЗ 2м/с']
# ['23.10.2011', '+8°C', '754мм.рт.ст.', 'З 2м/с']
# ['24.10.2011', '+4°C', '752мм.рт.ст.', 'СВ 2м/с']
# ['25.10.2011', '+4°C', '754мм.рт.ст.', 'СВ 3м/с']
# ['26.10.2011', '+3°C', '757мм.рт.ст.', 'СВ 2м/с']
# ['27.10.2011', '+3°C', '755мм.рт.ст.', 'С 3м/с']
# ['28.10.2011', '+1°C', '758мм.рт.ст.', 'СЗ 2м/с']
# ['29.10.2011', '+1°C', '758мм.рт.ст.', 'З 3м/с']
# ['30.10.2011', '+3°C', '748мм.рт.ст.', 'З 3м/с']
# ['31.10.2011', '+7°C', '746мм.рт.ст.', 'З 2м/с']
# ['1.11.2011', '+7°C', '744мм.рт.ст.', 'ЮЗ 2м/с']
# ['2.11.2011', '+6°C', '751мм.рт.ст.', 'С 1м/с']
# ['3.11.2011', '+5°C', '748мм.рт.ст.', 'ЮЗ 5м/с']
# ['4.11.2011', '+1°C', '746мм.рт.ст.', 'С 2м/с']
# ['5.11.2011', '-7°C', '755мм.рт.ст.', 'С 3м/с']
# ['6.11.2011', '-9°C', '758мм.рт.ст.', 'СВ 3м/с']
# ['7.11.2011', '-5°C', '758мм.рт.ст.', 'СЗ 3м/с']
# ['8.11.2011', '-3°C', '747мм.рт.ст.', 'Ю 4м/с']
# ['9.11.2011', '-4°C', '738мм.рт.ст.', 'В 3м/с']
# ['10.11.2011', '0°C', '750мм.рт.ст.', 'ЮВ 2м/с']
# ['11.11.2011', '-1°C', '755мм.рт.ст.', 'СВ 2м/с']
# ['12.11.2011', '-2°C', '757мм.рт.ст.', 'С 1м/с']
# ['13.11.2011', '-3°C', '760мм.рт.ст.', 'СЗ 2м/с']
# ['14.11.2011', '-2°C', '751мм.рт.ст.', 'З 2м/с']
# ['15.11.2011', '-2°C', '740мм.рт.ст.', 'З 3м/с']
# ['16.11.2011', '-6°C', '744мм.рт.ст.', 'ЮЗ 3м/с']
# ['17.11.2011', '-6°C', '745мм.рт.ст.', 'ЮЗ 3м/с']
# ['18.11.2011', '-5°C', '746мм.рт.ст.', 'С 4м/с']
# ['19.11.2011', '-5°C', '751мм.рт.ст.', 'ЮЗ 2м/с']
# ['20.11.2011', '0°C', '737мм.рт.ст.', 'СЗ 3м/с']
# ['21.11.2011', '-4°C', '751мм.рт.ст.', 'СЗ 4м/с']
# ['22.11.2011', '-7°C', '748мм.рт.ст.', 'З 3м/с']
# ['23.11.2011', '-12°C', '758мм.рт.ст.', 'СВ 2м/с']
# ['24.11.2011', '-13°C', '762мм.рт.ст.', 'З 1м/с']
# ['25.11.2011', '-8°C', '754мм.рт.ст.', 'ЮЗ 2м/с']
# ['26.11.2011', '-5°C', '755мм.рт.ст.', 'ЮЗ 2м/с']
# ['27.11.2011', '-9°C', '751мм.рт.ст.', 'Ю 3м/с']
# ['28.11.2011', '-5°C', '748мм.рт.ст.', 'Ю 5м/с']
# ['29.11.2011', '-5°C', '751мм.рт.ст.', 'В 2м/с']
# ['30.11.2011', '-1°C', '746мм.рт.ст.', 'В 1м/с']
# ['1.12.2011', '-5°C', '749мм.рт.ст.', 'В 1м/с']
# ['2.12.2011', '-6°C', '754мм.рт.ст.', 'СВ 2м/с']
# ['3.12.2011', '-4°C', '757мм.рт.ст.', 'ЮЗ 2м/с']
# ['4.12.2011', '-6°C', '754мм.рт.ст.', 'ЮЗ 3м/с']
# ['5.12.2011', '-1°C', '750мм.рт.ст.', 'ЮЗ 4м/с']
# ['6.12.2011', '0°C', '753мм.рт.ст.', 'ЮЗ 4м/с']
# ['7.12.2011', '-7°C', '755мм.рт.ст.', 'ЮВ 3м/с']
# ['8.12.2011', '-10°C', '757мм.рт.ст.', 'ЮВ 2м/с']
# ['9.12.2011', '-7°C', '758мм.рт.ст.', 'В 2м/с']
# ['10.12.2011', '-12°C', '758мм.рт.ст.', 'ЮВ 2м/с']
# ['11.12.2011', '-14°C', '755мм.рт.ст.', 'В 1м/с']
# ['12.12.2011', '-9°C', '747мм.рт.ст.', 'В 2м/с']
# ['13.12.2011', '-5°C', '757мм.рт.ст.', 'С 2м/с']
# ['14.12.2011', '-11°C', '763мм.рт.ст.', 'В 1м/с']
# ['15.12.2011', '-8°C', '762мм.рт.ст.', 'ЮЗ 2м/с']
# ['16.12.2011', '-9°C', '763мм.рт.ст.', 'ЮВ 1м/с']
# ['17.12.2011', '-13°C', '763мм.рт.ст.', 'ЮВ 3м/с']
# ['18.12.2011', '-12°C', '767мм.рт.ст.', 'ЮВ 3м/с']
# ['19.12.2011', '-11°C', '768мм.рт.ст.', 'Ю 4м/с']
# ['20.12.2011', '-8°C', '766мм.рт.ст.', 'ЮВ 3м/с']
# ['21.12.2011', '-7°C', '759мм.рт.ст.', 'ЮВ 4м/с']
# ['22.12.2011', '-10°C', '755мм.рт.ст.', 'Ю 2м/с']
# ['23.12.2011', '-9°C', '752мм.рт.ст.', 'ЮВ 2м/с']
# ['24.12.2011', '-5°C', '750мм.рт.ст.', 'З 1м/с']
# ['25.12.2011', '-8°C', '752мм.рт.ст.', 'Ш']
# ['26.12.2011', '-8°C', '748мм.рт.ст.', 'З 4м/с']
# ['27.12.2011', '0°C', '736мм.рт.ст.', 'З 2м/с']
# ['28.12.2011', '+1°C', '729мм.рт.ст.', 'СЗ 4м/с']
# ['29.12.2011', '-3°C', '748мм.рт.ст.', 'СЗ 4м/с']
# ['30.12.2011', '-3°C', '753мм.рт.ст.', 'ЮЗ 2м/с']
# ['31.12.2011', '-8°C', '752мм.рт.ст.', 'ЮВ 2м/с']
# ['1.01.2012', '-5°C', '753мм.рт.ст.', 'В 2м/с']
# ['2.01.2012', '-6°C', '751мм.рт.ст.', 'В 2м/с']
# ['3.01.2012', '-6°C', '752мм.рт.ст.', 'В 1м/с']
# ['4.01.2012', '-11°C', '749мм.рт.ст.', 'Ю 2м/с']
# ['5.01.2012', '-4°C', '749мм.рт.ст.', 'Ю 2м/с']
# ['6.01.2012', '-1°C', '754мм.рт.ст.', 'Ю 3м/с']
# ['7.01.2012', '-8°C', '756мм.рт.ст.', 'ЮВ 2м/с']
# ['8.01.2012', '-10°C', '759мм.рт.ст.', 'ЮВ 3м/с']
# ['9.01.2012', '-11°C', '758мм.рт.ст.', 'В 4м/с']
# ['10.01.2012', '-11°C', '753мм.рт.ст.', 'В 2м/с']
# ['11.01.2012', '-10°C', '750мм.рт.ст.', 'ЮЗ 1м/с']
# ['12.01.2012', '-10°C', '749мм.рт.ст.', 'Ю 2м/с']
# ['13.01.2012', '-4°C', '747мм.рт.ст.', 'Ю 2м/с']
# ['14.01.2012', '-3°C', '749мм.рт.ст.', 'ЮВ 2м/с']
# ['15.01.2012', '-3°C', '754мм.рт.ст.', 'В 2м/с']
# ['16.01.2012', '-6°C', '754мм.рт.ст.', 'ЮВ 3м/с']
# ['17.01.2012', '-4°C', '754мм.рт.ст.', 'ЮВ 4м/с']
# ['18.01.2012', '-7°C', '758мм.рт.ст.', 'В 4м/с']
# ['19.01.2012', '-11°C', '762мм.рт.ст.', 'В 2м/с']
# ['20.01.2012', '-13°C', '764мм.рт.ст.', 'В 2м/с']
# ['21.01.2012', '-14°C', '769мм.рт.ст.', 'ЮВ 2м/с']
# ['22.01.2012', '-12°C', '769мм.рт.ст.', 'В 2м/с']
# ['23.01.2012', '-9°C', '767мм.рт.ст.', 'В 2м/с']
# ['24.01.2012', '-6°C', '763мм.рт.ст.', 'В 2м/с']
# ['25.01.2012', '-6°C', '764мм.рт.ст.', 'В 2м/с']
# ['26.01.2012', '-8°C', '770мм.рт.ст.', 'В 3м/с']
# ['27.01.2012', '-9°C', '769мм.рт.ст.', 'СВ 3м/с']
# ['28.01.2012', '-10°C', '765мм.рт.ст.', 'В 1м/с']
# ['29.01.2012', '-10°C', '767мм.рт.ст.', 'СЗ 1м/с']
# ['30.01.2012', '-16°C', '766мм.рт.ст.', 'СВ 2м/с']
# ['31.01.2012', '-17°C', '767мм.рт.ст.', 'В 4м/с']
# ['1.02.2012', '-19°C', '772мм.рт.ст.', 'В 3м/с']
# ['2.02.2012', '-19°C', '772мм.рт.ст.', 'В 2м/с']
# ['3.02.2012', '-19°C', '777мм.рт.ст.', 'В 1м/с']
# ['4.02.2012', '-15°C', '776мм.рт.ст.', 'С 2м/с']
# ['5.02.2012', '-14°C', '770мм.рт.ст.', 'СВ 2м/с']
# ['7.02.2012', '-13°C', '769мм.рт.ст.', 'В 2м/с']
# ['8.02.2012', '-13°C', '760мм.рт.ст.', 'В 5м/с']
# ['9.02.2012', '-12°C', '756мм.рт.ст.', 'В 3м/с']
# ['10.02.2012', '-17°C', '762мм.рт.ст.', 'ЮВ 2м/с']
# ['11.02.2012', '-14°C', '763мм.рт.ст.', 'ЮВ 2м/с']
# ['12.02.2012', '-17°C', '766мм.рт.ст.', 'Ш']
# ['13.02.2012', '-17°C', '764мм.рт.ст.', 'ЮВ 1м/с']
# ['14.02.2012', '-13°C', '764мм.рт.ст.', 'В 2м/с']
# ['15.02.2012', '-11°C', '758мм.рт.ст.', 'ЮВ 4м/с']
# ['16.02.2012', '-10°C', '758мм.рт.ст.', 'ЮВ 2м/с']
# ['17.02.2012', '-8°C', '758мм.рт.ст.', 'В 3м/с']
# ['18.02.2012', '-9°C', '760мм.рт.ст.', 'ЮВ 2м/с']
# ['19.02.2012', '-6°C', '762мм.рт.ст.', 'СЗ 2м/с']
# ['20.02.2012', '-6°C', '765мм.рт.ст.', 'СЗ 2м/с']
# ['21.02.2012', '-5°C', '761мм.рт.ст.', 'З 1м/с']
# ['22.02.2012', '-10°C', '757мм.рт.ст.', 'Ю 2м/с']
# ['23.02.2012', '-8°C', '756мм.рт.ст.', 'Ю 2м/с']
# ['24.02.2012', '-8°C', '751мм.рт.ст.', 'ЮВ 3м/с']
# ['25.02.2012', '-10°C', '746мм.рт.ст.', 'ЮВ 4м/с']
# ['26.02.2012', '-9°C', '745мм.рт.ст.', 'В 5м/с']
# ['27.02.2012', '-9°C', '746мм.рт.ст.', 'В 4м/с']
# ['28.02.2012', '-3°C', '749мм.рт.ст.', 'В 2м/с']
# ['29.02.2012', '-1°C', '745мм.рт.ст.', 'ЮВ 2м/с']
# ['1.03.2012', '-3°C', '744мм.рт.ст.', 'ЮВ 2м/с']
# ['2.03.2012', '-3°C', '740мм.рт.ст.', 'В 2м/с']
# ['3.03.2012', '-4°C', '736мм.рт.ст.', 'В 2м/с']
# ['4.03.2012', '-3°C', '741мм.рт.ст.', 'ЮВ 2м/с']
# ['5.03.2012', '-3°C', '740мм.рт.ст.', 'С 3м/с']
# ['6.03.2012', '-3°C', '741мм.рт.ст.', 'В 2м/с']
# ['7.03.2012', '-6°C', '746мм.рт.ст.', 'В 2м/с']
# ['8.03.2012', '-7°C', '750мм.рт.ст.', 'В 2м/с']
# ['9.03.2012', '-6°C', '749мм.рт.ст.', 'ЮВ 2м/с']
# ['10.03.2012', '-13°C', '754мм.рт.ст.', 'В 2м/с']
# ['11.03.2012', '-10°C', '756мм.рт.ст.', 'ЮВ 1м/с']
# ['12.03.2012', '-12°C', '755мм.рт.ст.', 'Ю 2м/с']
# ['13.03.2012', '-11°C', '740мм.рт.ст.', 'В 3м/с']
# ['14.03.2012', '-5°C', '728мм.рт.ст.', 'В 3м/с']
# ['15.03.2012', '-1°C', '736мм.рт.ст.', 'З 2м/с']
# ['16.03.2012', '-3°C', '743мм.рт.ст.', 'СЗ 2м/с']
# ['17.03.2012', '-6°C', '743мм.рт.ст.', 'З 3м/с']
# ['18.03.2012', '+1°C', '742мм.рт.ст.', 'З 4м/с']
# ['19.03.2012', '+6°C', '747мм.рт.ст.', 'СЗ 1м/с']
# ['20.03.2012', '0°C', '743мм.рт.ст.', 'Ю 3м/с']
# ['21.03.2012', '+1°C', '737мм.рт.ст.', 'ЮЗ 5м/с']
# ['22.03.2012', '+3°C', '742мм.рт.ст.', 'СЗ 2м/с']
# ['23.03.2012', '0°C', '742мм.рт.ст.', 'З 3м/с']
# ['24.03.2012', '-2°C', '740мм.рт.ст.', 'С 2м/с']
# ['25.03.2012', '-1°C', '747мм.рт.ст.', 'СЗ 3м/с']
# ['26.03.2012', '-3°C', '747мм.рт.ст.', 'ЮВ 3м/с']
# ['27.03.2012', '0°C', '732мм.рт.ст.', 'ЮЗ 3м/с']
# ['28.03.2012', '-3°C', '738мм.рт.ст.', 'З 3м/с']
# ['29.03.2012', '-2°C', '746мм.рт.ст.', 'ЮЗ 3м/с']
# ['30.03.2012', '+2°C', '741мм.рт.ст.', 'ЮЗ 5м/с']
# ['31.03.2012', '+3°C', '739мм.рт.ст.', 'ЮВ 3м/с']
# ['1.04.2012', '+3°C', '736мм.рт.ст.', 'Ю 2м/с']
# ['2.04.2012', '+4°C', '742мм.рт.ст.', 'З 3м/с']
# ['3.04.2012', '+2°C', '745мм.рт.ст.', 'ЮЗ 3м/с']
# ['4.04.2012', '+4°C', '755мм.рт.ст.', 'З 3м/с']
# ['5.04.2012', '+8°C', '751мм.рт.ст.', 'Ю 3м/с']
# ['6.04.2012', '+3°C', '749мм.рт.ст.', 'С 1м/с']
# ['7.04.2012', '+9°C', '748мм.рт.ст.', 'ЮВ 2м/с']
# ['8.04.2012', '+12°C', '743мм.рт.ст.', 'ЮВ 3м/с']
# ['9.04.2012', '+19°C', '743мм.рт.ст.', 'ЮВ 2м/с']
# ['10.04.2012', '+22°C', '746мм.рт.ст.', 'ЮВ 2м/с']
# ['11.04.2012', '+12°C', '746мм.рт.ст.', 'З 4м/с']
# ['12.04.2012', '+14°C', '750мм.рт.ст.', 'СВ 2м/с']
# ['13.04.2012', '+21°C', '740мм.рт.ст.', 'Ю 4м/с']
# ['14.04.2012', '+17°C', '749мм.рт.ст.', 'З 3м/с']
# ['15.04.2012', '+20°C', '752мм.рт.ст.', 'СВ 1м/с']
# ['16.04.2012', '+25°C', '748мм.рт.ст.', 'ЮВ 2м/с']
# ['17.04.2012', '+29°C', '746мм.рт.ст.', 'ЮВ 3м/с']
# ['18.04.2012', '+25°C', '744мм.рт.ст.', 'ЮЗ 3м/с']
# ['19.04.2012', '+24°C', '745мм.рт.ст.', 'СВ 2м/с']
# ['20.04.2012', '+25°C', '747мм.рт.ст.', 'В 3м/с']
# ['21.04.2012', '+28°C', '747мм.рт.ст.', 'ЮВ 3м/с']
# ['22.04.2012', '+17°C', '746мм.рт.ст.', 'В 1м/с']
# ['23.04.2012', '+25°C', '747мм.рт.ст.', 'ЮВ 1м/с']
# ['24.04.2012', '+22°C', '747мм.рт.ст.', 'З 3м/с']
# ['25.04.2012', '+23°C', '752мм.рт.ст.', 'СЗ 1м/с']
# ['26.04.2012', '+25°C', '751мм.рт.ст.', 'С 2м/с']
# ['27.04.2012', '+25°C', '749мм.рт.ст.', 'З 1м/с']
# ['28.04.2012', '+24°C', '750мм.рт.ст.', 'СЗ 2м/с']
# ['29.04.2012', '+22°C', '748мм.рт.ст.', 'З 3м/с']
# ['30.04.2012', '+6°C', '743мм.рт.ст.', 'С 2м/с']
# ['1.05.2012', '+11°C', '745мм.рт.ст.', 'С 2м/с']
# ['2.05.2012', '+14°C', '740мм.рт.ст.', 'С 3м/с']
# ['3.05.2012', '+13°C', '740мм.рт.ст.', 'З 2м/с']
# ['4.05.2012', '+18°C', '741мм.рт.ст.', 'З 3м/с']
# ['5.05.2012', '+16°C', '751мм.рт.ст.', 'З 1м/с']
# ['6.05.2012', '+21°C', '751мм.рт.ст.', 'Ю 3м/с']
# ['7.05.2012', '+27°C', '752мм.рт.ст.', 'З 2м/с']
# ['8.05.2012', '+27°C', '753мм.рт.ст.', 'З 2м/с']
# ['9.05.2012', '+29°C', '757мм.рт.ст.', 'З 2м/с']
# ['10.05.2012', '+30°C', '758мм.рт.ст.', 'ЮЗ 3м/с']
# ['11.05.2012', '+26°C', '755мм.рт.ст.', 'С 2м/с']
# ['12.05.2012', '+21°C', '748мм.рт.ст.', 'Ш']
# ['13.05.2012', '+29°C', '746мм.рт.ст.', 'З 2м/с']
# ['14.05.2012', '+24°C', '748мм.рт.ст.', 'ЮВ 2м/с']
# ['15.05.2012', '+21°C', '752мм.рт.ст.', 'СВ 3м/с']
# ['16.05.2012', '+22°C', '754мм.рт.ст.', 'В 2м/с']
# ['17.05.2012', '+21°C', '753мм.рт.ст.', 'З 1м/с']
# ['18.05.2012', '+25°C', '754мм.рт.ст.', 'В 2м/с']
# ['19.05.2012', '+27°C', '758мм.рт.ст.', 'З 2м/с']
# ['20.05.2012', '+27°C', '758мм.рт.ст.', 'З 1м/с']
# ['21.05.2012', '+27°C', '755мм.рт.ст.', 'С 1м/с']
# ['22.05.2012', '+27°C', '752мм.рт.ст.', 'З 1м/с']
# ['23.05.2012', '+26°C', '746мм.рт.ст.', 'Ю 1м/с']
# ['24.05.2012', '+12°C', '749мм.рт.ст.', 'С 4м/с']
# ['25.05.2012', '+15°C', '749мм.рт.ст.', 'В 3м/с']
# ['26.05.2012', '+21°C', '743мм.рт.ст.', 'В 2м/с']
# ['27.05.2012', '+25°C', '741мм.рт.ст.', 'З 2м/с']
# ['28.05.2012', '+18°C', '743мм.рт.ст.', 'З 3м/с']
# ['29.05.2012', '+25°C', '746мм.рт.ст.', 'З 2м/с']
# ['30.05.2012', '+27°C', '749мм.рт.ст.', 'ЮЗ 2м/с']
# ['31.05.2012', '+23°C', '746мм.рт.ст.', 'ЮВ 1м/с']
# ['1.06.2012', '+26°C', '746мм.рт.ст.', 'З 2м/с']
# ['2.06.2012', '+25°C', '746мм.рт.ст.', 'З 2м/с']
# ['3.06.2012', '+20°C', '743мм.рт.ст.', 'З 5м/с']
# ['4.06.2012', '+12°C', '746мм.рт.ст.', 'З 2м/с']
# ['5.06.2012', '+21°C', '749мм.рт.ст.', 'ЮЗ 2м/с']
# ['6.06.2012', '+22°C', '747мм.рт.ст.', 'Ш']
# ['7.06.2012', '+29°C', '743мм.рт.ст.', 'В 2м/с']
# ['8.06.2012', '+33°C', '741мм.рт.ст.', 'ЮЗ 3м/с']
# ['9.06.2012', '+25°C', '746мм.рт.ст.', 'З 3м/с']
# ['10.06.2012', '+24°C', '749мм.рт.ст.', 'СЗ 3м/с']
# ['11.06.2012', '+20°C', '746мм.рт.ст.', 'З 1м/с']
# ['12.06.2012', '+27°C', '748мм.рт.ст.', 'З 2м/с']
# ['13.06.2012', '+34°C', '743мм.рт.ст.', 'ЮЗ 3м/с']
# ['14.06.2012', '+33°C', '746мм.рт.ст.', 'ЮЗ 3м/с']
# ['15.06.2012', '+31°C', '749мм.рт.ст.', 'СВ 2м/с']
# ['16.06.2012', '+31°C', '743мм.рт.ст.', 'В 3м/с']
# ['17.06.2012', '+26°C', '740мм.рт.ст.', 'С 3м/с']
# ['18.06.2012', '+23°C', '744мм.рт.ст.', 'СЗ 3м/с']
# ['19.06.2012', '+23°C', '743мм.рт.ст.', 'С 3м/с']
# ['20.06.2012', '+21°C', '743мм.рт.ст.', 'СВ 2м/с']
# ['21.06.2012', '+26°C', '743мм.рт.ст.', 'СВ 2м/с']
# ['22.06.2012', '+19°C', '742мм.рт.ст.', 'Ш']
# ['23.06.2012', '+24°C', '745мм.рт.ст.', 'С 3м/с']
# ['24.06.2012', '+24°C', '747мм.рт.ст.', 'С 2м/с']
# ['25.06.2012', '+26°C', '748мм.рт.ст.', 'С 2м/с']
# ['26.06.2012', '+29°C', '749мм.рт.ст.', 'Ю 3м/с']
# ['27.06.2012', '+30°C', '746мм.рт.ст.', 'ЮВ 1м/с']
# ['28.06.2012', '+29°C', '743мм.рт.ст.', 'В 2м/с']
# ['29.06.2012', '+25°C', '740мм.рт.ст.', 'СЗ 2м/с']
# ['30.06.2012', '+26°C', '746мм.рт.ст.', 'З 2м/с']
# ['1.07.2012', '+24°C', '749мм.рт.ст.', 'С 3м/с']
# ['2.07.2012', '+19°C', '749мм.рт.ст.', 'СВ 2м/с']
# ['3.07.2012', '+25°C', '747мм.рт.ст.', 'ЮВ 2м/с']
# ['4.07.2012', '+28°C', '749мм.рт.ст.', 'ЮЗ 1м/с']
# ['5.07.2012', '+29°C', '750мм.рт.ст.', 'СЗ 2м/с']
# ...
# ['21.10.2022', '+7°C', '747мм.рт.ст.', 'СЗ 2м/с']
# ['22.10.2022', '+5°C', '755мм.рт.ст.', 'СЗ 1м/с']
# ['23.10.2022', '+3°C', '756мм.рт.ст.', 'Ю 1м/с']
# ['24.10.2022', '+6°C', '746мм.рт.ст.', 'Ю 2м/с']
# ['25.10.2022', '+3°C', '749мм.рт.ст.', 'СЗ 1м/с']
# ['26.10.2022', '+3°C', '758мм.рт.ст.', 'СВ 1м/с']
# ['27.10.2022', '+4°C', '760мм.рт.ст.', 'ЮВ 2м/с']
# ['28.10.2022', '+3°C', '756мм.рт.ст.', 'В 2м/с']
# ['29.10.2022', '+3°C', '752мм.рт.ст.', 'Ю 1м/с']
# ['30.10.2022', '+4°C', '737мм.рт.ст.', 'Ю 2м/с']
# ['31.10.2022', '+3°C', '737мм.рт.ст.', 'З 1м/с']
# ['1.11.2022', '+1°C', '737мм.рт.ст.', 'СЗ 3м/с']
# ['2.11.2022', '0°C', '735мм.рт.ст.', 'СЗ 3м/с']
# ['3.11.2022', '+1°C', '741мм.рт.ст.', 'С 1м/с']
# ['4.11.2022', '+2°C', '748мм.рт.ст.', 'З 1м/с']
# ['5.11.2022', '+3°C', '752мм.рт.ст.', 'З 2м/с']
# ['6.11.2022', '+2°C', '758мм.рт.ст.', 'З 1м/с']
# ['7.11.2022', '+1°C', '757мм.рт.ст.', 'ЮЗ 2м/с']
# ['9.11.2022', '+5°C', '755мм.рт.ст.', 'ЮЗ 3м/с']
# ['10.11.2022', '+6°C', '756мм.рт.ст.', 'ЮЗ 3м/с']
# ['11.11.2022', '+6°C', '756мм.рт.ст.', 'ЮЗ 5м/с']
# ['12.11.2022', '+6°C', '745мм.рт.ст.', 'ЮЗ 4м/с']
# ['13.11.2022', '+6°C', '728мм.рт.ст.', 'З 4м/с']
# ['14.11.2022', '-2°C', '740мм.рт.ст.', 'СЗ 5м/с']
# ['15.11.2022', '-4°C', '747мм.рт.ст.', 'СЗ 3м/с']
# ['16.11.2022', '-2°C', '749мм.рт.ст.', 'З 1м/с']
# ['17.11.2022', '-2°C', '749мм.рт.ст.', 'В 4м/с']
# ['18.11.2022', '0°C', '746мм.рт.ст.', 'В 3м/с']
# ['19.11.2022', '+1°C', '752мм.рт.ст.', 'С 1м/с']
# ['20.11.2022', '0°C', '752мм.рт.ст.', 'В 2м/с']
# ['21.11.2022', '-2°C', '753мм.рт.ст.', 'В 1м/с']
# ['22.11.2022', '-1°C', '753мм.рт.ст.', 'В 3м/с']
# ['23.11.2022', '0°C', '744мм.рт.ст.', 'В 1м/с']
# ['24.11.2022', '+1°C', '748мм.рт.ст.', 'З 1м/с']
# ['25.11.2022', '+1°C', '758мм.рт.ст.', 'В 2м/с']
# ['26.11.2022', '-4°C', '764мм.рт.ст.', 'В 3м/с']
# ['27.11.2022', '-7°C', '764мм.рт.ст.', 'СВ 3м/с']
# ['28.11.2022', '-5°C', '767мм.рт.ст.', 'СВ 2м/с']
# ['29.11.2022', '-7°C', '770мм.рт.ст.', 'СВ 2м/с']
# ['30.11.2022', '-10°C', '770мм.рт.ст.', 'С 1м/с']
# ['1.12.2022', '-7°C', '769мм.рт.ст.', 'СЗ 1м/с']
# ['2.12.2022', '-10°C', '773мм.рт.ст.', 'В 2м/с']
# ['3.12.2022', '-12°C', '776мм.рт.ст.', 'В 1м/с']
# ['4.12.2022', '-10°C', '776мм.рт.ст.', 'СЗ 2м/с']
# ['5.12.2022', '-12°C', '768мм.рт.ст.', 'С 1м/с']
# ['6.12.2022', '-10°C', '767мм.рт.ст.', 'В 1м/с']
# ['7.12.2022', '-13°C', '769мм.рт.ст.', 'В 2м/с']
# ['8.12.2022', '-13°C', '768мм.рт.ст.', 'В 2м/с']
# ['9.12.2022', '-10°C', '765мм.рт.ст.', 'В 1м/с']
# ['10.12.2022', '-7°C', '761мм.рт.ст.', 'ЮВ 3м/с']
# ['11.12.2022', '-6°C', '759мм.рт.ст.', 'ЮВ 2м/с']
# ['12.12.2022', '-6°C', '759мм.рт.ст.', 'ЮВ 2м/с']
# ['13.12.2022', '-6°C', '760мм.рт.ст.', 'В 3м/с']
# ['14.12.2022', '-5°C', '756мм.рт.ст.', 'В 3м/с']
# ['15.12.2022', '-5°C', '760мм.рт.ст.', 'В 1м/с']
# ['16.12.2022', '-4°C', '758мм.рт.ст.', 'В 1м/с']
# ['17.12.2022', '-3°C', '759мм.рт.ст.', 'В 2м/с']
# ['18.12.2022', '+1°C', '751мм.рт.ст.', 'ЮЗ 1м/с']
# ['19.12.2022', '-6°C', '753мм.рт.ст.', 'З 3м/с']
# ['20.12.2022', '-8°C', '755мм.рт.ст.', 'З 2м/с']
# ['21.12.2022', '-5°C', '755мм.рт.ст.', 'В 2м/с']
# ['22.12.2022', '-2°C', '752мм.рт.ст.', 'Ю 3м/с']
# ['23.12.2022', '+1°C', '752мм.рт.ст.', 'Ю 2м/с']
# ['24.12.2022', '-2°C', '755мм.рт.ст.', 'Ю 2м/с']
# ['25.12.2022', '-7°C', '755мм.рт.ст.', 'ЮВ 2м/с']
# ['26.12.2022', '-4°C', '758мм.рт.ст.', 'С 1м/с']
# ['27.12.2022', '-3°C', '758мм.рт.ст.', 'СВ 1м/с']
# ['28.12.2022', '-6°C', '753мм.рт.ст.', 'В 2м/с']
# ['29.12.2022', '-7°C', '751мм.рт.ст.', 'В 1м/с']
# ['30.12.2022', '-6°C', '755мм.рт.ст.', 'В 1м/с']
# ['31.12.2022', '-3°C', '751мм.рт.ст.', 'В 3м/с']
# ['1.01.2023', '0°C', '750мм.рт.ст.', 'ЮЗ 1м/с']
# ['2.01.2023', '+2°C', '737мм.рт.ст.', 'СЗ 4м/с']
# ['3.01.2023', '-1°C', '747мм.рт.ст.', 'З 2м/с']
# ['4.01.2023', '-2°C', '739мм.рт.ст.', 'СЗ 1м/с']
# ['5.01.2023', '-6°C', '743мм.рт.ст.', 'Ю 2м/с']
# ['6.01.2023', '-13°C', '739мм.рт.ст.', 'СЗ 3м/с']
# ['7.01.2023', '-24°C', '749мм.рт.ст.', 'СЗ 2м/с']
# ['8.01.2023', '-22°C', '754мм.рт.ст.', 'СЗ 4м/с']
# ['9.01.2023', '-25°C', '766мм.рт.ст.', 'СЗ 1м/с']
# ['10.01.2023', '-23°C', '775мм.рт.ст.', 'З 1м/с']
# ['11.01.2023', '-21°C', '777мм.рт.ст.', 'ЮЗ 1м/с']
# ['12.01.2023', '-15°C', '772мм.рт.ст.', 'Ю 1м/с']
# ['13.01.2023', '-14°C', '768мм.рт.ст.', 'В 1м/с']
# ['14.01.2023', '-12°C', '768мм.рт.ст.', 'ЮВ 2м/с']
# ['15.01.2023', '-10°C', '767мм.рт.ст.', 'В 2м/с']
# ['16.01.2023', '-12°C', '763мм.рт.ст.', 'В 4м/с']
# ['17.01.2023', '-12°C', '764мм.рт.ст.', 'В 3м/с']
# ['18.01.2023', '-10°C', '766мм.рт.ст.', 'В 2м/с']
# ['19.01.2023', '-9°C', '767мм.рт.ст.', 'В 3м/с']
# ['20.01.2023', '-10°C', '770мм.рт.ст.', 'В 2м/с']
# ['21.01.2023', '-9°C', '773мм.рт.ст.', 'В 2м/с']
# ['22.01.2023', '-7°C', '773мм.рт.ст.', 'В 2м/с']
# ['23.01.2023', '-7°C', '771мм.рт.ст.', 'З 2м/с']
# ['24.01.2023', '-6°C', '767мм.рт.ст.', 'З 1м/с']
# ['25.01.2023', '-7°C', '761мм.рт.ст.', 'ЮЗ 1м/с']
# ['26.01.2023', '-3°C', '757мм.рт.ст.', 'З 3м/с']
# ['27.01.2023', '-5°C', '755мм.рт.ст.', 'ЮЗ 3м/с']
# ['28.01.2023', '-6°C', '756мм.рт.ст.', 'З 1м/с']
# ['29.01.2023', '-9°C', '753мм.рт.ст.', 'ЮЗ 1м/с']
# ['30.01.2023', '-4°C', '749мм.рт.ст.', 'ЮВ 3м/с']
# ['31.01.2023', '-2°C', '749мм.рт.ст.', 'Ю 2м/с']
# ['1.02.2023', '-8°C', '752мм.рт.ст.', 'В 2м/с']
# ['2.02.2023', '-5°C', '752мм.рт.ст.', 'ЮВ 1м/с']
# ['3.02.2023', '-7°C', '752мм.рт.ст.', 'В 2м/с']
# ['4.02.2023', '-7°C', '753мм.рт.ст.', 'В 2м/с']
# ['5.02.2023', '-6°C', '755мм.рт.ст.', 'З 1м/с']
# ['6.02.2023', '-6°C', '758мм.рт.ст.', 'З 1м/с']
# ['7.02.2023', '-9°C', '764мм.рт.ст.', 'С 1м/с']
# ['8.02.2023', '-9°C', '764мм.рт.ст.', 'З 1м/с']
# ['9.02.2023', '-6°C', '762мм.рт.ст.', 'СЗ 1м/с']
# ['10.02.2023', '-7°C', '760мм.рт.ст.', 'З 3м/с']
# ['11.02.2023', '-4°C', '755мм.рт.ст.', 'ЮЗ 2м/с']
# ['12.02.2023', '-6°C', '752мм.рт.ст.', 'ЮВ 3м/с']
# ['13.02.2023', '-3°C', '749мм.рт.ст.', 'ЮВ 3м/с']
# ['14.02.2023', '-7°C', '746мм.рт.ст.', 'В 3м/с']
# ['15.02.2023', '-8°C', '746мм.рт.ст.', 'СВ 3м/с']
# ['16.02.2023', '-2°C', '752мм.рт.ст.', 'В 3м/с']
# ['17.02.2023', '-5°C', '751мм.рт.ст.', 'С 1м/с']
# ['18.02.2023', '-6°C', '747мм.рт.ст.', 'В 1м/с']
# ['19.02.2023', '-12°C', '743мм.рт.ст.', 'СВ 3м/с']
# ['20.02.2023', '-10°C', '739мм.рт.ст.', 'В 2м/с']
# ['21.02.2023', '-3°C', '733мм.рт.ст.', 'ЮВ 1м/с']
# ['22.02.2023', '-4°C', '728мм.рт.ст.', 'СЗ 1м/с']
# ['23.02.2023', '-11°C', '738мм.рт.ст.', 'З 2м/с']
# ['24.02.2023', '-10°C', '749мм.рт.ст.', 'ЮЗ 3м/с']
# ['25.02.2023', '-3°C', '749мм.рт.ст.', 'Ю 2м/с']
# ['26.02.2023', '+1°C', '750мм.рт.ст.', 'ЮВ 2м/с']
# ['27.02.2023', '+3°C', '749мм.рт.ст.', 'ЮЗ 3м/с']
# ['28.02.2023', '-2°C', '745мм.рт.ст.', 'ЮЗ 3м/с']
# ['1.03.2023', '-3°C', '737мм.рт.ст.', 'З 2м/с']
# ['2.03.2023', '-4°C', '740мм.рт.ст.', 'ЮЗ 3м/с']
# ['3.03.2023', '-2°C', '741мм.рт.ст.', 'ЮЗ 4м/с']
# ['4.03.2023', '0°C', '738мм.рт.ст.', 'ЮЗ 2м/с']
# ['5.03.2023', '0°C', '733мм.рт.ст.', 'ЮЗ 1м/с']
# ['6.03.2023', '+1°C', '741мм.рт.ст.', 'ЮЗ 2м/с']
# ['7.03.2023', '-1°C', '746мм.рт.ст.', 'ЮЗ 3м/с']
# ['8.03.2023', '+1°C', '747мм.рт.ст.', 'ЮЗ 2м/с']
# ['9.03.2023', '+2°C', '746мм.рт.ст.', 'Ю 3м/с']
# ['10.03.2023', '+4°C', '740мм.рт.ст.', 'Ю 2м/с']
# ['11.03.2023', '+2°C', '751мм.рт.ст.', 'СВ 1м/с']
# ['12.03.2023', '+4°C', '748мм.рт.ст.', 'В 3м/с']
# ['13.03.2023', '+2°C', '747мм.рт.ст.', 'З 1м/с']
# ['14.03.2023', '+2°C', '758мм.рт.ст.', 'ЮЗ 3м/с']
# ['15.03.2023', '+5°C', '760мм.рт.ст.', 'Ю 2м/с']
# ['16.03.2023', '+7°C', '755мм.рт.ст.', 'В 3м/с']
# ['17.03.2023', '+10°C', '752мм.рт.ст.', 'ЮВ 2м/с']
# ['18.03.2023', '+1°C', '758мм.рт.ст.', 'С 3м/с']
# ['19.03.2023', '+2°C', '759мм.рт.ст.', 'В 3м/с']
# ['20.03.2023', '+1°C', '756мм.рт.ст.', 'ЮВ 2м/с']
# ['21.03.2023', '+11°C', '750мм.рт.ст.', 'Ю 2м/с']
# ['22.03.2023', '+10°C', '748мм.рт.ст.', 'ЮЗ 2м/с']
# ['23.03.2023', '+9°C', '752мм.рт.ст.', 'ЮЗ 2м/с']
# ['24.03.2023', '+14°C', '747мм.рт.ст.', 'Ю 3м/с']
# ['25.03.2023', '+13°C', '746мм.рт.ст.', 'ЮЗ 2м/с']
# ['26.03.2023', '+18°C', '745мм.рт.ст.', 'ЮЗ 3м/с']
# ['27.03.2023', '+16°C', '740мм.рт.ст.', 'ЮЗ 3м/с']
# ['28.03.2023', '+13°C', '746мм.рт.ст.', 'СЗ 2м/с']
# ['29.03.2023', '+10°C', '749мм.рт.ст.', 'В 4м/с']
# ['30.03.2023', '+12°C', '748мм.рт.ст.', 'В 3м/с']
# ['31.03.2023', '+6°C', '746мм.рт.ст.', 'ЮВ 1м/с']
# ['1.04.2023', '+10°C', '750мм.рт.ст.', 'Ю 3м/с']
# ['2.04.2023', '+16°C', '749мм.рт.ст.', 'В 3м/с']
# ['3.04.2023', '+16°C', '750мм.рт.ст.', 'ЮВ 2м/с']
# ['4.04.2023', '+18°C', '751мм.рт.ст.', 'ЮВ 2м/с']
# ['5.04.2023', '+19°C', '749мм.рт.ст.', 'С 1м/с']
# ['6.04.2023', '+17°C', '749мм.рт.ст.', 'С 2м/с']
# ['7.04.2023', '+10°C', '755мм.рт.ст.', 'В 3м/с']
# ['8.04.2023', '+10°C', '758мм.рт.ст.', 'В 3м/с']
# ['9.04.2023', '+13°C', '758мм.рт.ст.', 'В 2м/с']
# ['10.04.2023', '+15°C', '754мм.рт.ст.', 'С 2м/с']
# ['11.04.2023', '+16°C', '754мм.рт.ст.', 'З 2м/с']
# ['12.04.2023', '+18°C', '751мм.рт.ст.', 'В 2м/с']
# ['13.04.2023', '+20°C', '745мм.рт.ст.', 'СВ 3м/с']
# ['14.04.2023', '+7°C', '746мм.рт.ст.', 'СВ 5м/с']
# ['15.04.2023', '+7°C', '755мм.рт.ст.', 'С 4м/с']
# ['16.04.2023', '+13°C', '757мм.рт.ст.', 'СЗ 3м/с']
# ['17.04.2023', '+13°C', '761мм.рт.ст.', 'З 2м/с']
# ['18.04.2023', '+16°C', '759мм.рт.ст.', 'З 2м/с']
# ['19.04.2023', '+18°C', '757мм.рт.ст.', 'ЮЗ 2м/с']
# ['20.04.2023', '+18°C', '752мм.рт.ст.', 'ЮЗ 2м/с']
# ['21.04.2023', '+16°C', '747мм.рт.ст.', 'С 2м/с']
# ['22.04.2023', '+12°C', '741мм.рт.ст.', 'СЗ 2м/с']
# ['23.04.2023', '+18°C', '749мм.рт.ст.', 'З 2м/с']
# ['24.04.2023', '+21°C', '754мм.рт.ст.', 'ЮЗ 2м/с']
# ['25.04.2023', '+18°C', '752мм.рт.ст.', 'В 1м/с']
# ['26.04.2023', '+18°C', '746мм.рт.ст.', 'ЮЗ 3м/с']
# ['27.04.2023', '+22°C', '748мм.рт.ст.', 'ЮЗ 2м/с']
# ['28.04.2023', '+23°C', '749мм.рт.ст.', 'СЗ 2м/с']
# ['29.04.2023', '+25°C', '750мм.рт.ст.', 'В 2м/с']
# ['30.04.2023', '+27°C', '748мм.рт.ст.', 'В 2м/с']
# ['1.05.2023', '+30°C', '745мм.рт.ст.', 'ЮВ 3м/с']
# ['2.05.2023', '+21°C', '749мм.рт.ст.', 'СЗ 2м/с']
# ['3.05.2023', '+19°C', '753мм.рт.ст.', 'С 1м/с']
# ['4.05.2023', '+17°C', '755мм.рт.ст.', 'З 1м/с']
# ['5.05.2023', '+23°C', '752мм.рт.ст.', 'Ю 2м/с']
# ['6.05.2023', '+11°C', '749мм.рт.ст.', 'СЗ 3м/с']
# ['7.05.2023', '+11°C', '755мм.рт.ст.', 'СЗ 2м/с']
# ['8.05.2023', '+11°C', '757мм.рт.ст.', 'С 2м/с']
# ['9.05.2023', '+14°C', '756мм.рт.ст.', 'СВ 2м/с']
# ['10.05.2023', '+18°C', '751мм.рт.ст.', 'СВ 2м/с']
# ['11.05.2023', '+19°C', '751мм.рт.ст.', 'ЮЗ 1м/с']
# ['12.05.2023', '+11°C', '746мм.рт.ст.', 'СВ 3м/с']
# ['13.05.2023', '+21°C', '749мм.рт.ст.', 'СЗ 2м/с']
# ['14.05.2023', '+18°C', '750мм.рт.ст.', 'С 3м/с']
# ['15.05.2023', '+19°C', '751мм.рт.ст.', 'СЗ 2м/с']
# ['16.05.2023', '+21°C', '752мм.рт.ст.', 'Ш']
# ['17.05.2023', '+25°C', '752мм.рт.ст.', 'С 2м/с']
# ['18.05.2023', '+23°C', '751мм.рт.ст.', 'СВ 4м/с']
# ['19.05.2023', '+21°C', '752мм.рт.ст.', 'С 2м/с']
# ['20.05.2023', '+19°C', '754мм.рт.ст.', 'СВ 2м/с']
# ['21.05.2023', '+25°C', '756мм.рт.ст.', 'СВ 3м/с']
# ['22.05.2023', '+27°C', '756мм.рт.ст.', 'В 3м/с']
# ['23.05.2023', '+28°C', '755мм.рт.ст.', 'В 3м/с']
# ['24.05.2023', '+29°C', '755мм.рт.ст.', 'В 3м/с']
# ['25.05.2023', '+31°C', '754мм.рт.ст.', 'Ю 3м/с']
# ['26.05.2023', '+30°C', '751мм.рт.ст.', 'ЮВ 2м/с']
# ['27.05.2023', '+27°C', '749мм.рт.ст.', 'СВ 1м/с']
# ['28.05.2023', '+30°C', '746мм.рт.ст.', 'Ю 3м/с']
# ['29.05.2023', '+25°C', '752мм.рт.ст.', 'З 2м/с']
# ['30.05.2023', '+28°C', '749мм.рт.ст.', 'В 2м/с']
# ['31.05.2023', '+29°C', '743мм.рт.ст.', 'З 3м/с']
# ['1.06.2023', '+25°C', '746мм.рт.ст.', 'З 3м/с']
# ['2.06.2023', '+26°C', '742мм.рт.ст.', 'С 2м/с']
# ['3.06.2023', '+26°C', '748мм.рт.ст.', 'ЮЗ 2м/с']
# ['4.06.2023', '+24°C', '749мм.рт.ст.', 'С 2м/с']
# ['5.06.2023', '+21°C', '751мм.рт.ст.', 'С 2м/с']
# ['6.06.2023', '+20°C', '749мм.рт.ст.', 'СЗ 2м/с']
# ['7.06.2023', '+21°C', '751мм.рт.ст.', 'СЗ 2м/с']
# ['8.06.2023', '+24°C', '751мм.рт.ст.', 'З 3м/с']
# ['9.06.2023', '+24°C', '751мм.рт.ст.', 'ЮЗ 2м/с']
# ['10.06.2023', '+18°C', '751мм.рт.ст.', 'СВ 2м/с']
# ['11.06.2023', '+16°C', '755мм.рт.ст.', 'С 2м/с']
# ['12.06.2023', '+13°C', '754мм.рт.ст.', 'С 3м/с']
# ['13.06.2023', '+21°C', '753мм.рт.ст.', 'СВ 3м/с']
# ['14.06.2023', '+23°C', '750мм.рт.ст.', 'СВ 2м/с']
# ['15.06.2023', '+24°C', '747мм.рт.ст.', 'СВ 3м/с']
# ['16.06.2023', '+21°C', '744мм.рт.ст.', 'С 2м/с']
# ['17.06.2023', '+28°C', '742мм.рт.ст.', 'СВ 3м/с']
# ['18.06.2023', '+20°C', '745мм.рт.ст.', 'С 4м/с']
# ['19.06.2023', '+15°C', '747мм.рт.ст.', 'СЗ 3м/с']
# ['20.06.2023', '+17°C', '744мм.рт.ст.', 'СЗ 1м/с']
# ['21.06.2023', '+16°C', '746мм.рт.ст.', 'СЗ 3м/с']
# ['22.06.2023', '+16°C', '750мм.рт.ст.', 'СЗ 2м/с']
# ['23.06.2023', '+17°C', '749мм.рт.ст.', 'СЗ 2м/с']
# ['24.06.2023', '+20°C', '748мм.рт.ст.', 'ЮВ 1м/с']
# ['25.06.2023', '+20°C', '744мм.рт.ст.', 'С 2м/с']
# ['26.06.2023', '+22°C', '746мм.рт.ст.', 'С 2м/с']
# ['27.06.2023', '+24°C', '747мм.рт.ст.', 'С 1м/с']
# ['28.06.2023', '+23°C', '747мм.рт.ст.', 'ЮЗ 2м/с']
# ['29.06.2023', '+28°C', '745мм.рт.ст.', 'ЮВ 1м/с']
# ['30.06.2023', '+31°C', '738мм.рт.ст.', 'ЮВ 2м/с']
# ['1.07.2023', '+21°C', '737мм.рт.ст.', 'Ш']
# ['2.07.2023', '+23°C', '738мм.рт.ст.', 'СЗ 2м/с']
# ['3.07.2023', '+28°C', '744мм.рт.ст.', 'ЮЗ 3м/с']
# ['4.07.2023', '+29°C', '749мм.рт.ст.', 'З 1м/с']
# ['5.07.2023', '+31°C', '751мм.рт.ст.', 'С 1м/с']
# ['6.07.2023', '+30°C', '752мм.рт.ст.', 'З 2м/с']
# ['7.07.2023', '+31°C', '752мм.рт.ст.', 'СЗ 2м/с']
# ['8.07.2023', '+32°C', '749мм.рт.ст.', 'ЮВ 1м/с']
# ['9.07.2023', '+33°C', '743мм.рт.ст.', 'В 3м/с']
# ['10.07.2023', '+35°C', '738мм.рт.ст.', 'ЮВ 2м/с']
# ['11.07.2023', '+29°C', '737мм.рт.ст.', 'ЮВ 2м/с']
# ['12.07.2023', '+19°C', '744мм.рт.ст.', 'З 3м/с']
# ['13.07.2023', '+17°C', '744мм.рт.ст.', 'З 2м/с']
# ['14.07.2023', '+21°C', '743мм.рт.ст.', 'З 3м/с']
# ['15.07.2023', '+24°C', '740мм.рт.ст.', 'ЮВ 2м/с']
# ['16.07.2023', '+16°C', '740мм.рт.ст.', 'СВ 2м/с']
# ['17.07.2023', '+17°C', '742мм.рт.ст.', 'СЗ 2м/с']
# ['18.07.2023', '+20°C', '739мм.рт.ст.', 'З 2м/с']
# ['19.07.2023', '+20°C', '737мм.рт.ст.', 'ЮЗ 2м/с']
# ['20.07.2023', '+23°C', '742мм.рт.ст.', 'ЮЗ 3м/с']
# ['21.07.2023', '+25°C', '746мм.рт.ст.', 'ЮЗ 3м/с']
# ['22.07.2023', '+24°C', '746мм.рт.ст.', 'З 2м/с']
# ['23.07.2023', '+24°C', '747мм.рт.ст.', 'З 2м/с']
# ['24.07.2023', '+25°C', '744мм.рт.ст.', 'ЮЗ 2м/с']
# ['25.07.2023', '+27°C', '745мм.рт.ст.', 'З 2м/с']
# ['26.07.2023', '+30°C', '746мм.рт.ст.', 'З 3м/с']
# ['27.07.2023', '+32°C', '746мм.рт.ст.', 'ЮЗ 2м/с']
# ['28.07.2023', '+35°C', '745мм.рт.ст.', 'З 2м/с']
# ['29.07.2023', '+34°C', '740мм.рт.ст.', 'ЮВ 3м/с']
# ['30.07.2023', '+26°C', '741мм.рт.ст.', 'Ю 2м/с']
# ['31.07.2023', '+22°C', '745мм.рт.ст.', 'З 3м/с']
# ['1.08.2023', '+28°C', '746мм.рт.ст.', 'СЗ 2м/с']
# ['2.08.2023', '+29°C', '747мм.рт.ст.', 'ЮЗ 2м/с']
# ['3.08.2023', '+25°C', '747мм.рт.ст.', 'З 1м/с']
# ['4.08.2023', '+30°C', '748мм.рт.ст.', 'ЮЗ 2м/с']
# ['5.08.2023', '+33°C', '749мм.рт.ст.', 'ЮЗ 2м/с']
# ['6.08.2023', '+30°C', '750мм.рт.ст.', 'С 2м/с']
# ['7.08.2023', '+29°C', '748мм.рт.ст.', 'СВ 2м/с']
# ['8.08.2023', '+30°C', '745мм.рт.ст.', 'С 2м/с']
# ['9.08.2023', '+29°C', '749мм.рт.ст.', 'С 2м/с']
# ['10.08.2023', '+32°C', '753мм.рт.ст.', 'З 3м/с']
# ['11.08.2023', '+31°C', '755мм.рт.ст.', 'С 2м/с']
# ['12.08.2023', '+29°C', '755мм.рт.ст.', 'В 1м/с']
# ['13.08.2023', '+30°C', '755мм.рт.ст.', 'В 2м/с']
# ['14.08.2023', '+27°C', '752мм.рт.ст.', 'В 1м/с']
# ['15.08.2023', '+28°C', '749мм.рт.ст.', 'СЗ 2м/с']
# ['16.08.2023', '+22°C', '749мм.рт.ст.', 'С 1м/с']
# ['17.08.2023', '+30°C', '749мм.рт.ст.', 'СВ 3м/с']
# ['18.08.2023', '+33°C', '752мм.рт.ст.', 'ЮВ 2м/с']
# ['19.08.2023', '+31°C', '752мм.рт.ст.', 'С 1м/с']
# ['20.08.2023', '+27°C', '751мм.рт.ст.', 'СЗ 1м/с']
# ['21.08.2023', '+25°C', '746мм.рт.ст.', 'СЗ 2м/с']
# ['22.08.2023', '+16°C', '744мм.рт.ст.', 'СВ 1м/с']
# ['23.08.2023', '+21°C', '743мм.рт.ст.', 'З 2м/с']
# ['24.08.2023', '+15°C', '746мм.рт.ст.', 'СВ 2м/с']
# ['25.08.2023', '+18°C', '746мм.рт.ст.', 'ЮЗ 1м/с']
# ['26.08.2023', '+16°C', '747мм.рт.ст.', 'З 2м/с']
# ['27.08.2023', '+17°C', '743мм.рт.ст.', 'ЮЗ 3м/с']
# ['28.08.2023', '+13°C', '740мм.рт.ст.', 'СЗ 4м/с']
# ['29.08.2023', '+20°C', '743мм.рт.ст.', 'СЗ 3м/с']
# ['30.08.2023', '+20°C', '746мм.рт.ст.', 'СЗ 3м/с']
# ['31.08.2023', '+21°C', '748мм.рт.ст.', 'СЗ 4м/с']
# ['1.09.2023', '+24°C', '749мм.рт.ст.', 'СЗ 2м/с']
# ['2.09.2023', '+23°C', '751мм.рт.ст.', 'С 2м/с']
# ['3.09.2023', '+24°C', '753мм.рт.ст.', 'С 1м/с']
# ['4.09.2023', '+24°C', '753мм.рт.ст.', 'ЮЗ 2м/с']
# ['5.09.2023', '+22°C', '753мм.рт.ст.', 'СЗ 1м/с']
# ['6.09.2023', '+25°C', '748мм.рт.ст.', 'ЮЗ 2м/с']
# ['7.09.2023', '+16°C', '746мм.рт.ст.', 'З 3м/с']

# %% [markdown]
# # Пояснение
#
# Ошибки "Parsing error" связаны с тем, что на сайте за этот день отсутствуют данные метеорологических наблюдений.
#
# ![Parsing_error.png](data:image/png;base64,...)
